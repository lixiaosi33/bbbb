# %%
import hmac,random,time
import hashlib
import json, requests

def getSign(data,secret):
    result = hmac.new(secret.encode("utf-8"), data.encode("utf-8"), hashlib.md5).hexdigest()
    return result

def doApiRequestWithApikey(url, cmds, api_key, api_secret):
    s_cmds = json.dumps(cmds)
    sign = getSign(s_cmds,api_secret)
    r = requests.post(url, data={'cmds': s_cmds, 'apikey': api_key,'sign':sign})
    print(r.text)

def post_order(api_key,api_secret,cmds):
    url = "https://api.bibox.com/v1/orderpending"
    doApiRequestWithApikey(url,cmds,api_key,api_secret)



api_key = '49d43ef25d6dca7c8396a36fbb368e8255ca2ac1'
api_secret = '4e9b9730a7cf5b3015e90346d65681aa15441959'

def buy(price_buy,vol_buy):
    account_type = 0 
    order_type = 2 
    order_side = 1 
    pair = 'CHS_USDT'
    #price = 
    #amount = 1

    cmds = [
        {
            'cmd':"orderpending/trade",
            'body':{
                'pair':pair,
                'account_type':account_type,
                'order_type':order_type,
                'order_side':order_side,
                'price':price_buy ,
                'amount':vol_buy
            }
        }
    ]
    post_order(api_key,api_secret,cmds)
    
def sell(price_buy,vol_buy):
    account_type = 0 
    order_type = 2 
    order_side = 2 
    pair = 'CHS_USDT'
    #price = 
    #amount = 1

    cmds = [
        {
            'cmd':"orderpending/trade",
            'body':{
                'pair':pair,
                'account_type':account_type,
                'order_type':order_type,
                'order_side':order_side,
                'price':price_buy ,
                'amount':vol_buy
            }
        }
    ]
    post_order(api_key,api_secret,cmds)
    
def get_price():
    url = "https://api.bibox.com/v1/mdata?cmd=depth&pair=CHS_USDT&size=10"
    r = requests.get(url)
    res = r.text
    rese = eval(res)
    ask1 = rese['result']['asks'][0]['price']
    avol1 = rese['result']['asks'][0]['volume']
    bid1 = rese['result']['bids'][0]['price']
    bvol1 = rese['result']['bids'][0]['volume']
    return float(ask1), float(bid1),float(avol1), float(bvol1)



count = 0
price = 0

def combine(pr,st,b1,a1):
    print ("pr before",pr,"st",st,a1,b1)
    bei = random.randint(-2, 2) 
    res = pr+st*bei
    print ("res_before",res,bei,st)
    st1 = 1
    if res>=(a1-st1):
        res = a1-st1
    if res<=(b1+st1):
        res = b1 + st1
    #print ("bei",bei,"res",res)
    print ("res_after",res)
    return int(res)    

while True:
    try:
        slee1 = random.randint(30,50)
        slee2 = random.randint(10,50)
        slee3 = random.randint(40,100)
        slee = random.choice([slee1,slee2,slee3])
        print ("sleep: "+str(slee)+"s")
        time.sleep(slee)
        count = count + 1
        ask1,bid1, avol1, bvol1 = get_price()
        print ("ask1",ask1,"bid1",bid1, "avol1",avol1,"bvol1",bvol1)
        if (avol1>40) & (bvol1>40):
            if count %1==0:
                if ask1*1e4-bid1*1e4>=5:
                    if price ==0:
                        price = int((ask1*1e4+bid1*1e4)/2)*1.0/1e4
                    else:
                        step = random.randint(2,10)*5
                        deltaP = combine(int(float(price)*1e4),step,bid1*1e4,ask1*1e4)
                        price = deltaP/1e4
                    print ("============price================",price)
                    dot = random.randint(1,10)
                    if dot in [1,2,3,4]:
                        vol = random.randint(10,20)
                    elif dot in [5,6,7]:
                        vol = random.randint(10,20) + random.randint(1,10)*1000/10000.0
                    elif dot in [8,9]:
                        vol = random.randint(10,20) + random.randint(1,100)*100/10000.0
                    else:
                        vol = random.randint(10,20) + random.randint(1,1000)*10/10000.0
                    print ("vol=========  ",vol)
                    #print ("make orders, price", price)
                    dir_flag = random.randint(0,1)
                    if dir_flag==0:
                        buy(price,vol)
                        sell(price,vol)    
                        print ("buy-sell:",price,vol)
                    else:
                        sell(price,vol) 
                        buy(price,vol)
                        print ("sell-buy:",price,vol)     
            else:
                pass
    except:
        pass
# Out:
# sleep: 36s
# ask1 1.2655 bid1 1.2167 avol1 41.8374 bvol1 107.19
# ============price================ 1.2411
# vol=========   20.48
# {"result":[{"result":"12420083579526933","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579526943","cmd":"orderpending/trade"}]}
# buy-sell: 1.2411 20.48
# sleep: 19s
# ask1 1.2655 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12411 st 30 12655.0 12166.999999999998
# res_before 12411 0 30
# res_after 12411
# ============price================ 1.2411
# vol=========   17.76
# {"result":[{"result":"12420083579528603","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579528616","cmd":"orderpending/trade"}]}
# buy-sell: 1.2411 17.76
# sleep: 43s
# ask1 1.2655 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12411 st 10 12655.0 12166.999999999998
# res_before 12401 -1 10
# res_after 12401
# ============price================ 1.2401
# vol=========   13
# {"result":[{"result":"12420083579532407","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579532425","cmd":"orderpending/trade"}]}
# sell-buy: 1.2401 13
# sleep: 73s
# ask1 1.2655 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12401 st 30 12655.0 12166.999999999998
# res_before 12431 1 30
# res_after 12431
# ============price================ 1.2431
# vol=========   18.22
# {"result":[{"result":"12420083579538777","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579538781","cmd":"orderpending/trade"}]}
# sell-buy: 1.2431 18.22
# sleep: 64s
# ask1 1.2684 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12431 st 30 12684.0 12166.999999999998
# res_before 12371 -2 30
# res_after 12371
# ============price================ 1.2371
# vol=========   13
# {"result":[{"result":"12420083579544569","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579544584","cmd":"orderpending/trade"}]}
# buy-sell: 1.2371 13
# sleep: 88s
# ask1 1.2673 bid1 1.2167 avol1 761.9924 bvol1 107.19
# pr before 12371 st 40 12673.000000000002 12166.999999999998
# res_before 12291 -2 40
# res_after 12291
# ============price================ 1.2291
# vol=========   11.5
# {"result":[{"result":"12420083579552261","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579552275","cmd":"orderpending/trade"}]}
# buy-sell: 1.2291 11.5
# sleep: 33s
# ask1 1.267 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12291 st 10 12669.999999999998 12166.999999999998
# res_before 12271 -2 10
# res_after 12271
# ============price================ 1.2271
# vol=========   17.0
# {"result":[{"result":"12420083579555388","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579555394","cmd":"orderpending/trade"}]}
# buy-sell: 1.2271 17.0
# sleep: 39s
# ask1 1.2665 bid1 1.2167 avol1 761.9924 bvol1 107.19
# pr before 12271 st 30 12665.0 12166.999999999998
# res_before 12331 2 30
# res_after 12331
# ============price================ 1.2331
# vol=========   15.6
# {"result":[{"result":"12420083579558976","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579558980","cmd":"orderpending/trade"}]}
# buy-sell: 1.2331 15.6
# sleep: 55s
# ask1 1.2659 bid1 1.2167 avol1 761.9924 bvol1 107.19
# pr before 12331 st 10 12659.0 12166.999999999998
# res_before 12311 -2 10
# res_after 12311
# ============price================ 1.2311
# vol=========   10
# {"result":[{"result":"12420083579563909","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579563915","cmd":"orderpending/trade"}]}
# sell-buy: 1.2311 10
# sleep: 11s
# ask1 1.2658 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12311 st 35 12658.0 12166.999999999998
# res_before 12276 -1 35
# res_after 12276
# ============price================ 1.2276
# vol=========   15.41
# {"result":[{"result":"12420083579565053","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579565066","cmd":"orderpending/trade"}]}
# sell-buy: 1.2276 15.41
# sleep: 43s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12276 st 25 12654.0 12166.999999999998
# res_before 12251 -1 25
# res_after 12251
# ============price================ 1.2251
# vol=========   12.66
# {"result":[{"result":"12420083579569286","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579569294","cmd":"orderpending/trade"}]}
# buy-sell: 1.2251 12.66
# sleep: 34s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12251 st 35 12654.0 12166.999999999998
# res_before 12321 2 35
# res_after 12321
# ============price================ 1.2321
# vol=========   14
# {"result":[{"result":"12420083579572517","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579572525","cmd":"orderpending/trade"}]}
# buy-sell: 1.2321 14
# sleep: 90s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12321 st 20 12654.0 12166.999999999998
# res_before 12281 -2 20
# res_after 12281
# ============price================ 1.2281
# vol=========   20.7
# {"result":[{"result":"12420083579581177","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579581183","cmd":"orderpending/trade"}]}
# buy-sell: 1.2281 20.7
# sleep: 45s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12281 st 40 12654.0 12166.999999999998
# res_before 12241 -1 40
# res_after 12241
# ============price================ 1.2241
# vol=========   16.54
# {"result":[{"result":"12420083579585066","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579585073","cmd":"orderpending/trade"}]}
# sell-buy: 1.2241 16.54
# sleep: 38s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12241 st 10 12654.0 12166.999999999998
# res_before 12261 2 10
# res_after 12261
# ============price================ 1.2261
# vol=========   13.111
# {"result":[{"result":"12420083579588416","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579588424","cmd":"orderpending/trade"}]}
# sell-buy: 1.2261 13.111
# sleep: 65s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12261 st 35 12654.0 12166.999999999998
# res_before 12331 2 35
# res_after 12331
# ============price================ 1.2331
# vol=========   16.021
# {"result":[{"result":"12420083579594045","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579594049","cmd":"orderpending/trade"}]}
# sell-buy: 1.2331 16.021
# sleep: 49s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12331 st 50 12654.0 12166.999999999998
# res_before 12381 1 50
# res_after 12381
# ============price================ 1.2381
# vol=========   16
# {"result":[{"result":"12420083579598895","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579598903","cmd":"orderpending/trade"}]}
# buy-sell: 1.2381 16
# sleep: 13s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12381 st 20 12654.0 12166.999999999998
# res_before 12401 1 20
# res_after 12401
# ============price================ 1.2401
# vol=========   12.1
# {"result":[{"result":"12420083579600158","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579600166","cmd":"orderpending/trade"}]}
# sell-buy: 1.2401 12.1
# sleep: 94s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12401 st 30 12654.0 12166.999999999998
# res_before 12401 0 30
# res_after 12401
# ============price================ 1.2401
# vol=========   19
# {"result":[{"result":"12420083579608657","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579608665","cmd":"orderpending/trade"}]}
# buy-sell: 1.2401 19
# sleep: 42s
# ask1 1.2654 bid1 1.2167 avol1 41.8374 bvol1 107.19
# pr before 12401 st 40 12654.0 12166.999999999998
# res_before 12401 0 40
# res_after 12401
# ============price================ 1.2401
# vol=========   10.9
# {"result":[{"result":"12420083579612451","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579612461","cmd":"orderpending/trade"}]}
# sell-buy: 1.2401 10.9
# sleep: 86s
# ask1 1.2652 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12401 st 45 12652.000000000002 12167.01
# res_before 12356 -1 45
# res_after 12356
# ============price================ 1.2356
# vol=========   13.2
# {"result":[{"result":"12420083579620154","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579620160","cmd":"orderpending/trade"}]}
# buy-sell: 1.2356 13.2
# sleep: 68s
# ask1 1.2647 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12356 st 30 12647.0 12167.01
# res_before 12296 -2 30
# res_after 12296
# ============price================ 1.2296
# vol=========   18.3
# {"result":[{"result":"12420083579626345","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579626360","cmd":"orderpending/trade"}]}
# sell-buy: 1.2296 18.3
# sleep: 33s
# ask1 1.2644 bid1 1.216701 avol1 803.8298 bvol1 82.615
# pr before 12296 st 10 12644.0 12167.01
# res_before 12306 1 10
# res_after 12306
# ============price================ 1.2306
# vol=========   13.6
# {"result":[{"result":"12420083579629333","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579629342","cmd":"orderpending/trade"}]}
# buy-sell: 1.2306 13.6
# sleep: 42s
# ask1 1.2643 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12306 st 45 12643.0 12167.01
# res_before 12216 -2 45
# res_after 12216
# ============price================ 1.2216
# vol=========   17.468
# {"result":[{"result":"12420083579633366","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579633374","cmd":"orderpending/trade"}]}
# buy-sell: 1.2216 17.468
# sleep: 16s
# ask1 1.2641 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12216 st 30 12641.0 12167.01
# res_before 12246 1 30
# res_after 12246
# ============price================ 1.2246
# vol=========   19.5
# {"result":[{"result":"12420083579634915","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579634919","cmd":"orderpending/trade"}]}
# sell-buy: 1.2246 19.5
# sleep: 48s
# ask1 1.2636 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12246 st 40 12636.0 12167.01
# res_before 12206 -1 40
# res_after 12206
# ============price================ 1.2206
# vol=========   17.727
# {"result":[{"result":"12420083579639461","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579639466","cmd":"orderpending/trade"}]}
# sell-buy: 1.2206 17.727
# sleep: 47s
# ask1 1.263 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12205 st 40 12629.999999999998 12167.01
# res_before 12165 -1 40
# res_after 12168.01
# ============price================ 1.2168
# vol=========   18
# {"result":[{"result":"12420083579644085","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579644097","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 18
# sleep: 34s
# ask1 1.263 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12168 st 50 12629.999999999998 12167.01
# res_before 12118 -1 50
# res_after 12168.01
# ============price================ 1.2168
# vol=========   11
# {"result":[{"result":"12420083579647441","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579647449","cmd":"orderpending/trade"}]}
# buy-sell: 1.2168 11
# sleep: 44s
# ask1 1.2697 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12168 st 45 12697.0 12167.01
# res_before 12078 -2 45
# res_after 12168.01
# ============price================ 1.2168
# vol=========   16
# {"result":[{"result":"12420083579651858","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579651867","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 16
# sleep: 43s
# ask1 1.269299 bid1 1.216701 avol1 135.9256 bvol1 82.615
# pr before 12168 st 25 12692.99 12167.01
# res_before 12168 0 25
# res_after 12168.01
# ============price================ 1.2168
# vol=========   11
# {"result":[{"result":"12420083579656060","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579656072","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 11
# sleep: 48s
# ask1 1.268699 bid1 1.216701 avol1 135.9256 bvol1 82.615
# pr before 12168 st 40 12686.99 12167.01
# res_before 12088 -2 40
# res_after 12168.01
# ============price================ 1.2168
# vol=========   11
# {"result":[{"result":"12420083579660749","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579660760","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 11
# sleep: 70s
# ask1 1.2683 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12168 st 45 12683.0 12167.01
# res_before 12123 -1 45
# res_after 12168.01
# ============price================ 1.2168
# vol=========   20.3
# {"result":[{"result":"12420083579667770","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579667781","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 20.3
# sleep: 37s
# ask1 1.268 bid1 1.216701 avol1 803.8298 bvol1 82.615
# pr before 12168 st 35 12680.0 12167.01
# res_before 12238 2 35
# res_after 12238
# ============price================ 1.2238
# vol=========   15
# {"result":[{"result":"12420083579671290","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579671301","cmd":"orderpending/trade"}]}
# sell-buy: 1.2238 15
# sleep: 38s
# ask1 1.2679 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12238 st 30 12679.0 12167.01
# res_before 12268 1 30
# res_after 12268
# ============price================ 1.2268
# vol=========   11.0
# {"result":[{"result":"12420083579674943","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579674951","cmd":"orderpending/trade"}]}
# sell-buy: 1.2268 11.0
# sleep: 47s
# ask1 1.2675 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12267 st 50 12675.0 12167.01
# res_before 12317 1 50
# res_after 12317
# ============price================ 1.2317
# vol=========   13.6
# {"result":[{"result":"12420083579679289","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579679298","cmd":"orderpending/trade"}]}
# buy-sell: 1.2317 13.6
# sleep: 25s
# ask1 1.267 bid1 1.216701 avol1 803.8298 bvol1 82.615
# pr before 12317 st 10 12669.999999999998 12167.01
# res_before 12337 2 10
# res_after 12337
# ============price================ 1.2337
# vol=========   12.46
# {"result":[{"result":"12420083579681761","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579681768","cmd":"orderpending/trade"}]}
# buy-sell: 1.2337 12.46
# sleep: 46s
# ask1 1.2667 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12337 st 15 12667.0 12167.01
# res_before 12352 1 15
# res_after 12352
# ============price================ 1.2352
# vol=========   14
# {"result":[{"result":"12420083579686090","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579686097","cmd":"orderpending/trade"}]}
# buy-sell: 1.2352 14
# sleep: 38s
# ask1 1.2662 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12352 st 15 12662.0 12167.01
# res_before 12367 1 15
# res_after 12367
# ============price================ 1.2367
# vol=========   14.5
# {"result":[{"result":"12420083579689583","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579689593","cmd":"orderpending/trade"}]}
# buy-sell: 1.2367 14.5
# sleep: 16s
# ask1 1.266 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12367 st 20 12660.0 12167.01
# res_before 12387 1 20
# res_after 12387
# ============price================ 1.2387
# vol=========   18.9
# {"result":[{"result":"12420083579691077","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579691085","cmd":"orderpending/trade"}]}
# sell-buy: 1.2387 18.9
# sleep: 42s
# ask1 1.2659 bid1 1.216701 avol1 803.8298 bvol1 82.615
# pr before 12387 st 50 12659.0 12167.01
# res_before 12337 -1 50
# res_after 12337
# ============price================ 1.2337
# vol=========   17
# {"result":[{"result":"12420083579694847","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579694854","cmd":"orderpending/trade"}]}
# buy-sell: 1.2337 17
# sleep: 45s
# ask1 1.2656 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12337 st 45 12656.0 12167.01
# res_before 12247 -2 45
# res_after 12247
# ============price================ 1.2247
# vol=========   10
# {"result":[{"result":"12420083579698895","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579698912","cmd":"orderpending/trade"}]}
# sell-buy: 1.2247 10
# sleep: 48s
# ask1 1.265 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12246 st 30 12649.999999999998 12167.01
# res_before 12276 1 30
# res_after 12276
# ============price================ 1.2276
# vol=========   16.7
# {"result":[{"result":"12420083579702949","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579702954","cmd":"orderpending/trade"}]}
# sell-buy: 1.2276 16.7
# sleep: 47s
# ask1 1.2647 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12276 st 50 12647.0 12167.01
# res_before 12176 -2 50
# res_after 12176
# ============price================ 1.2176
# vol=========   16.127
# {"result":[{"result":"12420083579707226","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579707232","cmd":"orderpending/trade"}]}
# sell-buy: 1.2176 16.127
# sleep: 42s
# ask1 1.2642 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12176 st 40 12642.0 12167.01
# res_before 12176 0 40
# res_after 12176
# ============price================ 1.2176
# vol=========   18
# {"result":[{"result":"12420083579711238","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579711251","cmd":"orderpending/trade"}]}
# sell-buy: 1.2176 18
# sleep: 64s
# ask1 1.2639 bid1 1.216701 avol1 803.8298 bvol1 82.615
# pr before 12176 st 25 12639.0 12167.01
# res_before 12176 0 25
# res_after 12176
# ============price================ 1.2176
# vol=========   20.7
# {"result":[{"result":"12420083579717323","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579717330","cmd":"orderpending/trade"}]}
# sell-buy: 1.2176 20.7
# sleep: 41s
# ask1 1.2699 bid1 1.216701 avol1 803.8298 bvol1 82.615
# pr before 12176 st 45 12699.0 12167.01
# res_before 12266 2 45
# res_after 12266
# ============price================ 1.2266
# vol=========   13
# {"result":[{"result":"12420083579721264","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579721275","cmd":"orderpending/trade"}]}
# sell-buy: 1.2266 13
# sleep: 46s
# ask1 1.2695 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12266 st 30 12695.0 12167.01
# res_before 12266 0 30
# res_after 12266
# ============price================ 1.2266
# vol=========   10.8
# {"result":[{"result":"12420083579725278","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579725285","cmd":"orderpending/trade"}]}
# buy-sell: 1.2266 10.8
# sleep: 44s
# ask1 1.2691 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12266 st 30 12690.999999999998 12167.01
# res_before 12326 2 30
# res_after 12326
# ============price================ 1.2326
# vol=========   19.0
# {"result":[{"result":"12420083579729234","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579729248","cmd":"orderpending/trade"}]}
# sell-buy: 1.2326 19.0
# sleep: 72s
# ask1 1.268399 bid1 1.216701 avol1 135.9256 bvol1 82.615
# pr before 12326 st 40 12683.99 12167.01
# res_before 12326 0 40
# res_after 12326
# ============price================ 1.2326
# vol=========   14.5
# {"result":[{"result":"12420083579735819","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579735828","cmd":"orderpending/trade"}]}
# buy-sell: 1.2326 14.5
# sleep: 57s
# ask1 1.2678 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12326 st 15 12678.0 12167.01
# res_before 12341 1 15
# res_after 12341
# ============price================ 1.2341
# vol=========   10.37
# {"result":[{"result":"12420083579741665","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579741672","cmd":"orderpending/trade"}]}
# buy-sell: 1.2341 10.37
# sleep: 90s
# ask1 1.267 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12341 st 15 12669.999999999998 12167.01
# res_before 12356 1 15
# res_after 12356
# ============price================ 1.2356
# vol=========   20
# {"result":[{"result":"12420083579750763","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579750767","cmd":"orderpending/trade"}]}
# sell-buy: 1.2356 20
# sleep: 96s
# ask1 1.2662 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12356 st 15 12662.0 12167.01
# res_before 12341 -1 15
# res_after 12341
# ============price================ 1.2341
# vol=========   13
# {"result":[{"result":"12420083579760021","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579760036","cmd":"orderpending/trade"}]}
# sell-buy: 1.2341 13
# sleep: 30s
# ask1 1.266 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12341 st 30 12660.0 12167.01
# res_before 12371 1 30
# res_after 12371
# ============price================ 1.2371
# vol=========   10.679
# {"result":[{"result":"12420083579762948","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579762966","cmd":"orderpending/trade"}]}
# buy-sell: 1.2371 10.679
# sleep: 12s
# ask1 1.2658 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12371 st 50 12658.0 12167.01
# res_before 12271 -2 50
# res_after 12271
# ============price================ 1.2271
# vol=========   16.99
# {"result":[{"result":"12420083579764134","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579764144","cmd":"orderpending/trade"}]}
# buy-sell: 1.2271 16.99
# sleep: 45s
# ask1 1.2653 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12271 st 30 12653.000000000002 12167.01
# res_before 12301 1 30
# res_after 12301
# ============price================ 1.2301
# vol=========   13.681000000000001
# {"result":[{"result":"12420083579768663","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579768671","cmd":"orderpending/trade"}]}
# sell-buy: 1.2301 13.681000000000001
# sleep: 65s
# ask1 1.2645 bid1 1.2301 avol1 41.8374 bvol1 13.681
# pr before 12301 st 10 12645.0 12301.0
# res_before 12281 -2 10
# res_after 12302.0
# ============price================ 1.2302
# vol=========   18
# {"result":[{"result":"12420083579774773","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579774786","cmd":"orderpending/trade"}]}
# buy-sell: 1.2302 18
# sleep: 32s
# ask1 1.2643 bid1 1.2301 avol1 41.8374 bvol1 13.681
# pr before 12302 st 10 12643.0 12301.0
# res_before 12292 -1 10
# res_after 12302.0
# ============price================ 1.2302
# vol=========   19.798000000000002
# {"result":[{"result":"12420083579777732","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579777745","cmd":"orderpending/trade"}]}
# buy-sell: 1.2302 19.798000000000002
# sleep: 30s
# ask1 1.2643 bid1 1.2301 avol1 41.8374 bvol1 13.681
# pr before 12302 st 30 12643.0 12301.0
# res_before 12362 2 30
# res_after 12362
# ============price================ 1.2362
# vol=========   15
# {"result":[{"result":"12420083579780449","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579780464","cmd":"orderpending/trade"}]}
# sell-buy: 1.2362 15
# sleep: 46s
# ask1 1.264 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12362 st 50 12640.0 12167.01
# res_before 12362 0 50
# res_after 12362
# ============price================ 1.2362
# vol=========   15
# {"result":[{"result":"12420083579784630","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579784642","cmd":"orderpending/trade"}]}
# buy-sell: 1.2362 15
# sleep: 39s
# ask1 1.2638 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12362 st 45 12638.0 12167.01
# res_before 12317 -1 45
# res_after 12317
# ============price================ 1.2317
# vol=========   12
# {"result":[{"result":"12420083579788714","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579788717","cmd":"orderpending/trade"}]}
# buy-sell: 1.2317 12
# sleep: 29s
# ask1 1.2638 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12317 st 45 12638.0 12167.01
# res_before 12272 -1 45
# res_after 12272
# ============price================ 1.2272
# vol=========   17.1
# {"result":[{"result":"12420083579791735","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579791742","cmd":"orderpending/trade"}]}
# sell-buy: 1.2272 17.1
# sleep: 68s
# ask1 1.2636 bid1 1.216701 avol1 41.8374 bvol1 82.615
# pr before 12272 st 40 12636.0 12167.01
# res_before 12192 -2 40
# res_after 12192
# ============price================ 1.2192
# vol=========   17.85
# {"result":[{"result":"12420083579798914","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579798924","cmd":"orderpending/trade"}]}
# sell-buy: 1.2192 17.85
# sleep: 35s
# ask1 1.263598 bid1 1.216701 avol1 135.9256 bvol1 82.615
# pr before 12192 st 45 12635.98 12167.01
# res_before 12282 2 45
# res_after 12282
# ============price================ 1.2282
# vol=========   19.1
# {"result":[{"result":"12420083579802539","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579802549","cmd":"orderpending/trade"}]}
# buy-sell: 1.2282 19.1
# sleep: 59s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12282 st 45 12300.0 12167.01
# res_before 12192 -2 45
# res_after 12192
# ============price================ 1.2192
# vol=========   10.9
# {"result":[{"result":"12420083579808588","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579808597","cmd":"orderpending/trade"}]}
# buy-sell: 1.2192 10.9
# sleep: 49s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12192 st 15 12300.0 12167.01
# res_before 12222 2 15
# res_after 12222
# ============price================ 1.2222
# vol=========   13
# {"result":[{"result":"12420083579813445","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579813458","cmd":"orderpending/trade"}]}
# buy-sell: 1.2222 13
# sleep: 73s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12222 st 15 12300.0 12167.01
# res_before 12192 -2 15
# res_after 12192
# ============price================ 1.2192
# vol=========   12.89
# {"result":[{"result":"12420083579820819","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579820827","cmd":"orderpending/trade"}]}
# sell-buy: 1.2192 12.89
# sleep: 36s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12192 st 10 12300.0 12167.01
# res_before 12212 2 10
# res_after 12212
# ============price================ 1.2212
# vol=========   18
# {"result":[{"result":"12420083579824496","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579824505","cmd":"orderpending/trade"}]}
# sell-buy: 1.2212 18
# sleep: 74s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12212 st 50 12300.0 12167.01
# res_before 12212 0 50
# res_after 12212
# ============price================ 1.2212
# vol=========   18.55
# {"result":[{"result":"12420083579831886","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579831892","cmd":"orderpending/trade"}]}
# buy-sell: 1.2212 18.55
# sleep: 42s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12212 st 45 12300.0 12167.01
# res_before 12257 1 45
# res_after 12257
# ============price================ 1.2257
# vol=========   17.96
# {"result":[{"result":"12420083579836523","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579836534","cmd":"orderpending/trade"}]}
# buy-sell: 1.2257 17.96
# sleep: 83s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12257 st 10 12300.0 12167.01
# res_before 12277 2 10
# res_after 12277
# ============price================ 1.2277
# vol=========   10
# {"result":[{"result":"12420083579844788","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579844796","cmd":"orderpending/trade"}]}
# buy-sell: 1.2277 10
# sleep: 45s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12277 st 50 12300.0 12167.01
# res_before 12377 2 50
# res_after 12299.0
# ============price================ 1.2299
# vol=========   10
# {"result":[{"result":"12420083579849536","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579849547","cmd":"orderpending/trade"}]}
# buy-sell: 1.2299 10
# sleep: 59s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 10 12300.0 12167.01
# res_before 12309 1 10
# res_after 12299.0
# ============price================ 1.2299
# vol=========   14.3
# {"result":[{"result":"12420083579856059","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579856075","cmd":"orderpending/trade"}]}
# buy-sell: 1.2299 14.3
# sleep: 88s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 45 12300.0 12167.01
# res_before 12209 -2 45
# res_after 12209
# ============price================ 1.2209
# vol=========   18.427
# {"result":[{"result":"12420083579865042","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579865052","cmd":"orderpending/trade"}]}
# sell-buy: 1.2209 18.427
# sleep: 44s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12209 st 10 12300.0 12167.01
# res_before 12229 2 10
# res_after 12229
# ============price================ 1.2229
# vol=========   16
# {"result":[{"result":"12420083579869400","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579869407","cmd":"orderpending/trade"}]}
# sell-buy: 1.2229 16
# sleep: 63s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 20 12300.0 12167.01
# res_before 12249 1 20
# res_after 12249
# ============price================ 1.2249
# vol=========   13.1
# {"result":[{"result":"12420083579875363","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579875379","cmd":"orderpending/trade"}]}
# buy-sell: 1.2249 13.1
# sleep: 67s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12249 st 15 12300.0 12167.01
# res_before 12219 -2 15
# res_after 12219
# ============price================ 1.2219
# vol=========   13
# {"result":[{"result":"12420083579881544","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579881553","cmd":"orderpending/trade"}]}
# buy-sell: 1.2219 13
# sleep: 65s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12219 st 35 12300.0 12167.01
# res_before 12149 -2 35
# res_after 12168.01
# ============price================ 1.2168
# vol=========   14
# {"result":[{"result":"12420083579887748","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579887755","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 14
# sleep: 40s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 30 12300.0 12167.01
# res_before 12198 1 30
# res_after 12198
# ============price================ 1.2198
# vol=========   19.8
# {"result":[{"result":"12420083579891390","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579891397","cmd":"orderpending/trade"}]}
# buy-sell: 1.2198 19.8
# sleep: 29s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12198 st 30 12300.0 12167.01
# res_before 12138 -2 30
# res_after 12168.01
# ============price================ 1.2168
# vol=========   11
# {"result":[{"result":"12420083579894145","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579894152","cmd":"orderpending/trade"}]}
# buy-sell: 1.2168 11
# sleep: 49s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 15 12300.0 12167.01
# res_before 12153 -1 15
# res_after 12168.01
# ============price================ 1.2168
# vol=========   16.6
# {"result":[{"result":"12420083579898540","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579898549","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 16.6
# sleep: 35s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 40 12300.0 12167.01
# res_before 12248 2 40
# res_after 12248
# ============price================ 1.2248
# vol=========   16.1
# {"result":[{"result":"12420083579901866","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579901875","cmd":"orderpending/trade"}]}
# buy-sell: 1.2248 16.1
# sleep: 64s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12248 st 30 12300.0 12167.01
# res_before 12308 2 30
# res_after 12299.0
# ============price================ 1.2299
# vol=========   11.4
# {"result":[{"result":"12420083579907797","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579907800","cmd":"orderpending/trade"}]}
# sell-buy: 1.2299 11.4
# sleep: 40s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 35 12300.0 12167.01
# res_before 12264 -1 35
# res_after 12264
# ============price================ 1.2264
# vol=========   13.0
# {"result":[{"result":"12420083579911584","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579911594","cmd":"orderpending/trade"}]}
# sell-buy: 1.2264 13.0
# sleep: 33s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12264 st 45 12300.0 12167.01
# res_before 12264 0 45
# res_after 12264
# ============price================ 1.2264
# vol=========   15
# {"result":[{"result":"12420083579914671","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579914681","cmd":"orderpending/trade"}]}
# buy-sell: 1.2264 15
# sleep: 92s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12264 st 50 12300.0 12167.01
# res_before 12364 2 50
# res_after 12299.0
# ============price================ 1.2299
# vol=========   18.2
# {"result":[{"result":"12420083579923363","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579923368","cmd":"orderpending/trade"}]}
# sell-buy: 1.2299 18.2
# sleep: 34s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 20 12300.0 12167.01
# res_before 12299 0 20
# res_after 12299.0
# ============price================ 1.2299
# vol=========   10
# {"result":[{"result":"12420083579926598","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579926605","cmd":"orderpending/trade"}]}
# buy-sell: 1.2299 10
# sleep: 32s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 50 12300.0 12167.01
# res_before 12299 0 50
# res_after 12299.0
# ============price================ 1.2299
# vol=========   15.4
# {"result":[{"result":"12420083579929594","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579929609","cmd":"orderpending/trade"}]}
# sell-buy: 1.2299 15.4
# sleep: 36s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 35 12300.0 12167.01
# res_before 12229 -2 35
# res_after 12229
# ============price================ 1.2229
# vol=========   17
# {"result":[{"result":"12420083579933106","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579933114","cmd":"orderpending/trade"}]}
# sell-buy: 1.2229 17
# sleep: 62s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 45 12300.0 12167.01
# res_before 12229 0 45
# res_after 12229
# ============price================ 1.2229
# vol=========   16
# {"result":[{"result":"12420083579939129","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579939138","cmd":"orderpending/trade"}]}
# buy-sell: 1.2229 16
# sleep: 42s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 50 12300.0 12167.01
# res_before 12229 0 50
# res_after 12229
# ============price================ 1.2229
# vol=========   17.56
# {"result":[{"result":"12420083579943383","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579943396","cmd":"orderpending/trade"}]}
# sell-buy: 1.2229 17.56
# sleep: 72s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 25 12300.0 12167.01
# res_before 12229 0 25
# res_after 12229
# ============price================ 1.2229
# vol=========   11
# {"result":[{"result":"12420083579950277","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579950292","cmd":"orderpending/trade"}]}
# sell-buy: 1.2229 11
# sleep: 50s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 20 12300.0 12167.01
# res_before 12249 1 20
# res_after 12249
# ============price================ 1.2249
# vol=========   13.07
# {"result":[{"result":"12420083579954908","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579954915","cmd":"orderpending/trade"}]}
# sell-buy: 1.2249 13.07
# sleep: 37s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12249 st 40 12300.0 12167.01
# res_before 12209 -1 40
# res_after 12209
# ============price================ 1.2209
# vol=========   13.38
# {"result":[{"result":"12420083579958212","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579958223","cmd":"orderpending/trade"}]}
# sell-buy: 1.2209 13.38
# sleep: 48s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12209 st 50 12300.0 12167.01
# res_before 12109 -2 50
# res_after 12168.01
# ============price================ 1.2168
# vol=========   13.14
# {"result":[{"result":"12420083579962464","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579962477","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 13.14
# sleep: 98s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 10 12300.0 12167.01
# res_before 12178 1 10
# res_after 12178
# ============price================ 1.2178
# vol=========   15
# {"result":[{"result":"12420083579971493","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579971496","cmd":"orderpending/trade"}]}
# buy-sell: 1.2178 15
# sleep: 41s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12178 st 30 12300.0 12167.01
# res_before 12178 0 30
# res_after 12178
# ============price================ 1.2178
# vol=========   10
# {"result":[{"result":"12420083579975327","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579975331","cmd":"orderpending/trade"}]}
# sell-buy: 1.2178 10
# sleep: 36s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12178 st 10 12300.0 12167.01
# res_before 12198 2 10
# res_after 12198
# ============price================ 1.2198
# vol=========   12.6
# {"result":[{"result":"12420083579978508","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579978520","cmd":"orderpending/trade"}]}
# buy-sell: 1.2198 12.6
# sleep: 15s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12198 st 10 12300.0 12167.01
# res_before 12198 0 10
# res_after 12198
# ============price================ 1.2198
# vol=========   15.1
# {"result":[{"result":"12420083579979929","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579979940","cmd":"orderpending/trade"}]}
# buy-sell: 1.2198 15.1
# sleep: 14s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12198 st 45 12300.0 12167.01
# res_before 12153 -1 45
# res_after 12168.01
# ============price================ 1.2168
# vol=========   14
# {"result":[{"result":"12420083579981227","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579981235","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 14
# sleep: 45s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 15 12300.0 12167.01
# res_before 12153 -1 15
# res_after 12168.01
# ============price================ 1.2168
# vol=========   18
# {"result":[{"result":"12420083579985168","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579985185","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 18
# sleep: 37s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 40 12300.0 12167.01
# res_before 12168 0 40
# res_after 12168.01
# ============price================ 1.2168
# vol=========   11.8
# {"result":[{"result":"12420083579988425","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579988437","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 11.8
# sleep: 100s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 30 12300.0 12167.01
# res_before 12228 2 30
# res_after 12228
# ============price================ 1.2228
# vol=========   12.8
# {"result":[{"result":"12420083579997320","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083579997335","cmd":"orderpending/trade"}]}
# buy-sell: 1.2228 12.8
# sleep: 49s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12228 st 35 12300.0 12167.01
# res_before 12298 2 35
# res_after 12298
# ============price================ 1.2298
# vol=========   14
# {"result":[{"result":"12420083580001762","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580001769","cmd":"orderpending/trade"}]}
# buy-sell: 1.2298 14
# sleep: 76s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12298 st 45 12300.0 12167.01
# res_before 12388 2 45
# res_after 12299.0
# ============price================ 1.2299
# vol=========   14.3
# {"result":[{"result":"12420083580008909","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580008920","cmd":"orderpending/trade"}]}
# buy-sell: 1.2299 14.3
# sleep: 31s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 25 12300.0 12167.01
# res_before 12349 2 25
# res_after 12299.0
# ============price================ 1.2299
# vol=========   15.5
# {"result":[{"result":"12420083580011536","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580011548","cmd":"orderpending/trade"}]}
# sell-buy: 1.2299 15.5
# sleep: 46s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 30 12300.0 12167.01
# res_before 12329 1 30
# res_after 12299.0
# ============price================ 1.2299
# vol=========   14
# {"result":[{"result":"12420083580016129","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580016192","cmd":"orderpending/trade"}]}
# buy-sell: 1.2299 14
# sleep: 45s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 25 12300.0 12167.01
# res_before 12349 2 25
# res_after 12299.0
# ============price================ 1.2299
# vol=========   15.6
# {"result":[{"result":"12420083580020700","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580020706","cmd":"orderpending/trade"}]}
# sell-buy: 1.2299 15.6
# sleep: 44s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 35 12300.0 12167.01
# res_before 12369 2 35
# res_after 12299.0
# ============price================ 1.2299
# vol=========   12.9
# {"result":[{"result":"12420083580024804","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580024814","cmd":"orderpending/trade"}]}
# sell-buy: 1.2299 12.9
# sleep: 49s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 15 12300.0 12167.01
# res_before 12299 0 15
# res_after 12299.0
# ============price================ 1.2299
# vol=========   20.3
# {"result":[{"result":"12420083580029320","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580029331","cmd":"orderpending/trade"}]}
# sell-buy: 1.2299 20.3
# sleep: 50s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12299 st 35 12300.0 12167.01
# res_before 12229 -2 35
# res_after 12229
# ============price================ 1.2229
# vol=========   11
# {"result":[{"result":"12420083580034275","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580034287","cmd":"orderpending/trade"}]}
# buy-sell: 1.2229 11
# sleep: 49s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 15 12300.0 12167.01
# res_before 12229 0 15
# res_after 12229
# ============price================ 1.2229
# vol=========   11.23
# {"result":[{"result":"12420083580038733","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580038740","cmd":"orderpending/trade"}]}
# sell-buy: 1.2229 11.23
# sleep: 33s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 25 12300.0 12167.01
# res_before 12279 2 25
# res_after 12279
# ============price================ 1.2279
# vol=========   10
# {"result":[{"result":"12420083580041963","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580041976","cmd":"orderpending/trade"}]}
# sell-buy: 1.2279 10
# sleep: 14s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12279 st 45 12300.0 12167.01
# res_before 12234 -1 45
# res_after 12234
# ============price================ 1.2234
# vol=========   20.5
# {"result":[{"result":"12420083580043358","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580043366","cmd":"orderpending/trade"}]}
# sell-buy: 1.2234 20.5
# sleep: 100s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12234 st 40 12300.0 12167.01
# res_before 12274 1 40
# res_after 12274
# ============price================ 1.2274
# vol=========   14.8
# {"result":[{"result":"12420083580053261","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580053266","cmd":"orderpending/trade"}]}
# sell-buy: 1.2274 14.8
# sleep: 43s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12274 st 30 12300.0 12167.01
# res_before 12214 -2 30
# res_after 12214
# ============price================ 1.2214
# vol=========   17.7
# {"result":[{"result":"12420083580057554","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580057568","cmd":"orderpending/trade"}]}
# buy-sell: 1.2214 17.7
# sleep: 38s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12214 st 40 12300.0 12167.01
# res_before 12254 1 40
# res_after 12254
# ============price================ 1.2254
# vol=========   19.0
# {"result":[{"result":"12420083580061079","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580061088","cmd":"orderpending/trade"}]}
# sell-buy: 1.2254 19.0
# sleep: 54s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12254 st 25 12300.0 12167.01
# res_before 12229 -1 25
# res_after 12229
# ============price================ 1.2229
# vol=========   11
# {"result":[{"result":"12420083580066200","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580066207","cmd":"orderpending/trade"}]}
# buy-sell: 1.2229 11
# sleep: 42s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12229 st 30 12300.0 12167.01
# res_before 12259 1 30
# res_after 12259
# ============price================ 1.2259
# vol=========   11.45
# {"result":[{"result":"12420083580070084","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580070094","cmd":"orderpending/trade"}]}
# buy-sell: 1.2259 11.45
# sleep: 35s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12259 st 20 12300.0 12167.01
# res_before 12239 -1 20
# res_after 12239
# ============price================ 1.2239
# vol=========   12
# {"result":[{"result":"12420083580073166","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580073180","cmd":"orderpending/trade"}]}
# buy-sell: 1.2239 12
# sleep: 48s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12239 st 30 12300.0 12167.01
# res_before 12179 -2 30
# res_after 12179
# ============price================ 1.2179
# vol=========   10
# {"result":[{"result":"12420083580077218","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580077228","cmd":"orderpending/trade"}]}
# sell-buy: 1.2179 10
# sleep: 42s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12179 st 35 12300.0 12167.01
# res_before 12179 0 35
# res_after 12179
# ============price================ 1.2179
# vol=========   12.2
# {"result":[{"result":"12420083580081334","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580081342","cmd":"orderpending/trade"}]}
# sell-buy: 1.2179 12.2
# sleep: 23s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12179 st 45 12300.0 12167.01
# res_before 12089 -2 45
# res_after 12168.01
# ============price================ 1.2168
# vol=========   13.6
# {"result":[{"result":"12420083580083486","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580083494","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 13.6
# sleep: 68s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12168 st 50 12300.0 12167.01
# res_before 12218 1 50
# res_after 12218
# ============price================ 1.2218
# vol=========   10
# {"result":[{"result":"12420083580089720","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580089728","cmd":"orderpending/trade"}]}
# sell-buy: 1.2218 10
# sleep: 36s
# ask1 1.23 bid1 1.216701 avol1 107.371 bvol1 82.615
# pr before 12218 st 30 12300.0 12167.01
# res_before 12158 -2 30
# res_after 12168.01
# ============price================ 1.2168
# vol=========   13.14
# {"result":[{"result":"12420083580093142","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580093146","cmd":"orderpending/trade"}]}
# buy-sell: 1.2168 13.14
# sleep: 79s
# ask1 1.23 bid1 1.216701 avol1 57.7543 bvol1 82.615
# pr before 12168 st 20 12300.0 12167.01
# res_before 12208 2 20
# res_after 12208
# ============price================ 1.2208
# vol=========   15
# {"result":[{"result":"12420083580100172","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580100187","cmd":"orderpending/trade"}]}
# buy-sell: 1.2208 15
# sleep: 28s
# ask1 1.23 bid1 1.216701 avol1 57.7543 bvol1 82.615
# pr before 12208 st 15 12300.0 12167.01
# res_before 12178 -2 15
# res_after 12178
# ============price================ 1.2178
# vol=========   19
# {"result":[{"result":"12420083580102412","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580102423","cmd":"orderpending/trade"}]}
# buy-sell: 1.2178 19
# sleep: 13s
# ask1 1.23 bid1 1.216701 avol1 57.7543 bvol1 82.615
# pr before 12178 st 25 12300.0 12167.01
# res_before 12203 1 25
# res_after 12203
# ============price================ 1.2203
# vol=========   12.75
# {"result":[{"result":"12420083580103419","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580103424","cmd":"orderpending/trade"}]}
# buy-sell: 1.2203 12.75
# sleep: 10s
# ask1 1.23 bid1 1.216701 avol1 57.7543 bvol1 82.615
# pr before 12203 st 45 12300.0 12167.01
# res_before 12113 -2 45
# res_after 12168.01
# ============price================ 1.2168
# vol=========   14
# {"result":[{"result":"12420083580104285","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580104291","cmd":"orderpending/trade"}]}
# sell-buy: 1.2168 14
# sleep: 50s
# ask1 1.23 bid1 1.216701 avol1 57.7543 bvol1 82.615
# pr before 12168 st 10 12300.0 12167.01
# res_before 12148 -2 10
# res_after 12168.01
# ============price================ 1.2168
# vol=========   11
# {"result":[{"result":"12420083580108606","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580108609","cmd":"orderpending/trade"}]}
# buy-sell: 1.2168 11
# sleep: 56s
# ask1 1.23 bid1 1.216701 avol1 57.7543 bvol1 82.615
# pr before 12168 st 30 12300.0 12167.01
# res_before 12138 -1 30
# res_after 12168.01
# ============price================ 1.2168
# vol=========   19.2
# {"result":[{"result":"12420083580113372","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083580113384","cmd":"orderpending/trade"}]}
# buy-sell: 1.2168 19.2
# sleep: 59s
# ask1 1.23 bid1 1.216701 avol1 57.7543 bvol1 82.615
# pr before 12168 st 30 12300.0 12167.01
# res_before 12228 2 30
# res_after 12228
# ============price================ 1.2228
# vol=========   17.3
# {"result":[{"result":"12420083580118320","cmd":"orderpending/trade"}]}
# ...
# {"result":[{"result":"12420083584239928","cmd":"orderpending/trade"}]}
# buy-sell: 1.2316 12.195
# sleep: 98s
# ask1 1.2376 bid1 1.215001 avol1 2025.6004 bvol1 82.7307
# pr before 12316 st 50 12376.0 12150.01
# res_before 12316 0 50
# res_after 12316
# ============price================ 1.2316
# vol=========   15.5
# {"result":[{"result":"12420083584249265","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584249286","cmd":"orderpending/trade"}]}
# buy-sell: 1.2316 15.5
# sleep: 48s
# ask1 1.2376 bid1 1.215001 avol1 2025.6004 bvol1 82.7307
# pr before 12316 st 20 12376.0 12150.01
# res_before 12336 1 20
# res_after 12336
# ============price================ 1.2336
# vol=========   15.92
# {"result":[{"result":"12420083584253987","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584253993","cmd":"orderpending/trade"}]}
# buy-sell: 1.2336 15.92
# sleep: 97s
# ask1 1.2376 bid1 1.215001 avol1 2025.6004 bvol1 82.7307
# pr before 12336 st 10 12376.0 12150.01
# res_before 12336 0 10
# res_after 12336
# ============price================ 1.2336
# vol=========   13
# {"result":[{"result":"12420083584263171","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584263179","cmd":"orderpending/trade"}]}
# sell-buy: 1.2336 13
# sleep: 32s
# ask1 1.2376 bid1 1.215001 avol1 2025.6004 bvol1 82.7307
# pr before 12336 st 35 12376.0 12150.01
# res_before 12266 -2 35
# res_after 12266
# ============price================ 1.2266
# vol=========   17
# {"result":[{"result":"12420083584266361","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584266381","cmd":"orderpending/trade"}]}
# buy-sell: 1.2266 17
# sleep: 41s
# ask1 1.2376 bid1 1.215001 avol1 2025.6004 bvol1 82.7307
# pr before 12266 st 45 12376.0 12150.01
# res_before 12356 2 45
# res_after 12356
# ============price================ 1.2356
# vol=========   17.54
# {"result":[{"result":"12420083584270490","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584270502","cmd":"orderpending/trade"}]}
# sell-buy: 1.2356 17.54
# sleep: 34s
# ask1 1.2376 bid1 1.215001 avol1 2025.6004 bvol1 82.7307
# pr before 12356 st 40 12376.0 12150.01
# res_before 12316 -1 40
# res_after 12316
# ============price================ 1.2316
# vol=========   10.4
# {"result":[{"result":"12420083584273878","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584273892","cmd":"orderpending/trade"}]}
# sell-buy: 1.2316 10.4
# sleep: 56s
# ask1 1.2376 bid1 1.215001 avol1 2025.6004 bvol1 82.7307
# pr before 12316 st 30 12376.0 12150.01
# res_before 12376 2 30
# res_after 12375.0
# ============price================ 1.2375
# vol=========   17
# {"result":[{"result":"12420083584279609","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584279625","cmd":"orderpending/trade"}]}
# sell-buy: 1.2375 17
# sleep: 86s
# ask1 1.2376 bid1 1.221301 avol1 2025.6004 bvol1 82.304
# pr before 12375 st 45 12376.0 12213.01
# res_before 12375 0 45
# res_after 12375.0
# ============price================ 1.2375
# vol=========   14.9
# {"result":[{"result":"12420083584288507","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584288518","cmd":"orderpending/trade"}]}
# buy-sell: 1.2375 14.9
# sleep: 44s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12375 st 45 12376.0 12311.0
# res_before 12285 -2 45
# res_after 12312.0
# ============price================ 1.2312
# vol=========   18
# {"result":[{"result":"12420083584293346","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584293360","cmd":"orderpending/trade"}]}
# buy-sell: 1.2312 18
# sleep: 55s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12312 st 20 12376.0 12311.0
# res_before 12352 2 20
# res_after 12352
# ============price================ 1.2352
# vol=========   13.4
# {"result":[{"result":"12420083584298909","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584298926","cmd":"orderpending/trade"}]}
# buy-sell: 1.2352 13.4
# sleep: 38s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12352 st 15 12376.0 12311.0
# res_before 12322 -2 15
# res_after 12322
# ============price================ 1.2322
# vol=========   17
# {"result":[{"result":"12420083584302671","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584302683","cmd":"orderpending/trade"}]}
# buy-sell: 1.2322 17
# sleep: 38s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12322 st 40 12376.0 12311.0
# res_before 12402 2 40
# res_after 12375.0
# ============price================ 1.2375
# vol=========   16.2
# {"result":[{"result":"12420083584306630","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584306637","cmd":"orderpending/trade"}]}
# buy-sell: 1.2375 16.2
# sleep: 52s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12375 st 40 12376.0 12311.0
# res_before 12295 -2 40
# res_after 12312.0
# ============price================ 1.2312
# vol=========   16
# {"result":[{"result":"12420083584311994","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584312001","cmd":"orderpending/trade"}]}
# sell-buy: 1.2312 16
# sleep: 43s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12312 st 15 12376.0 12311.0
# res_before 12342 2 15
# res_after 12342
# ============price================ 1.2342
# vol=========   12.239
# {"result":[{"result":"12420083584316491","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584316509","cmd":"orderpending/trade"}]}
# sell-buy: 1.2342 12.239
# sleep: 24s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12342 st 25 12376.0 12311.0
# res_before 12392 2 25
# res_after 12375.0
# ============price================ 1.2375
# vol=========   17.1
# {"result":[{"result":"12420083584319108","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584319119","cmd":"orderpending/trade"}]}
# sell-buy: 1.2375 17.1
# sleep: 79s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12375 st 20 12376.0 12311.0
# res_before 12415 2 20
# res_after 12375.0
# ============price================ 1.2375
# vol=========   19
# {"result":[{"result":"12420083584327232","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584327241","cmd":"orderpending/trade"}]}
# buy-sell: 1.2375 19
# sleep: 40s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12375 st 45 12376.0 12311.0
# res_before 12375 0 45
# res_after 12375.0
# ============price================ 1.2375
# vol=========   17.274
# {"result":[{"result":"12420083584331138","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584331151","cmd":"orderpending/trade"}]}
# sell-buy: 1.2375 17.274
# sleep: 58s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12375 st 15 12376.0 12311.0
# res_before 12390 1 15
# res_after 12375.0
# ============price================ 1.2375
# vol=========   16.4
# {"result":[{"result":"12420083584337002","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584337015","cmd":"orderpending/trade"}]}
# buy-sell: 1.2375 16.4
# sleep: 35s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12375 st 35 12376.0 12311.0
# res_before 12410 1 35
# res_after 12375.0
# ============price================ 1.2375
# vol=========   14.85
# {"result":[{"result":"12420083584340501","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584340508","cmd":"orderpending/trade"}]}
# buy-sell: 1.2375 14.85
# sleep: 31s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12375 st 15 12376.0 12311.0
# res_before 12345 -2 15
# res_after 12345
# ============price================ 1.2345
# vol=========   14
# {"result":[{"result":"12420083584343581","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584343594","cmd":"orderpending/trade"}]}
# sell-buy: 1.2345 14
# sleep: 39s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12345 st 35 12376.0 12311.0
# res_before 12345 0 35
# res_after 12345
# ============price================ 1.2345
# vol=========   17.05
# {"result":[{"result":"12420083584347169","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584347175","cmd":"orderpending/trade"}]}
# buy-sell: 1.2345 17.05
# sleep: 98s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12345 st 15 12376.0 12311.0
# res_before 12360 1 15
# res_after 12360
# ============price================ 1.236
# vol=========   19
# {"result":[{"result":"12420083584356642","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584356655","cmd":"orderpending/trade"}]}
# buy-sell: 1.236 19
# sleep: 29s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12360 st 10 12376.0 12311.0
# res_before 12340 -2 10
# res_after 12340
# ============price================ 1.234
# vol=========   10.5
# {"result":[{"result":"12420083584359589","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584359602","cmd":"orderpending/trade"}]}
# buy-sell: 1.234 10.5
# sleep: 92s
# ask1 1.2376 bid1 1.2311 avol1 2025.6004 bvol1 257.4013
# pr before 12340 st 45 12376.0 12311.0
# res_before 12340 0 45
# res_after 12340
# ============price================ 1.234
# vol=========   19.6
# {"result":[{"result":"12420083584369470","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584369489","cmd":"orderpending/trade"}]}
# buy-sell: 1.234 19.6
# sleep: 52s
# ask1 1.2376 bid1 1.2295 avol1 2025.6004 bvol1 64.4985
# pr before 12340 st 50 12376.0 12295.0
# res_before 12290 -1 50
# res_after 12296.0
# ============price================ 1.2296
# vol=========   10
# {"result":[{"result":"12420083584374818","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584374827","cmd":"orderpending/trade"}]}
# sell-buy: 1.2296 10
# sleep: 57s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12296 st 15 12376.0 12349.000000000002
# res_before 12266 -2 15
# res_after 12350.000000000002
# ============price================ 1.235
# vol=========   10
# {"result":[{"result":"12420083584380669","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584380683","cmd":"orderpending/trade"}]}
# buy-sell: 1.235 10
# sleep: 85s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12350 st 20 12376.0 12349.000000000002
# res_before 12370 1 20
# res_after 12370
# ============price================ 1.237
# vol=========   17.0
# {"result":[{"result":"12420083584388943","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584388950","cmd":"orderpending/trade"}]}
# sell-buy: 1.237 17.0
# sleep: 39s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12370 st 10 12376.0 12349.000000000002
# res_before 12360 -1 10
# res_after 12360
# ============price================ 1.236
# vol=========   16
# {"result":[{"result":"12420083584392696","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584392705","cmd":"orderpending/trade"}]}
# buy-sell: 1.236 16
# sleep: 50s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12360 st 25 12376.0 12349.000000000002
# res_before 12385 1 25
# res_after 12375.0
# ============price================ 1.2375
# vol=========   14.804
# {"result":[{"result":"12420083584397536","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584397548","cmd":"orderpending/trade"}]}
# sell-buy: 1.2375 14.804
# sleep: 86s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12375 st 40 12376.0 12349.000000000002
# res_before 12375 0 40
# res_after 12375.0
# ============price================ 1.2375
# vol=========   18.6
# {"result":[{"result":"12420083584405880","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584405896","cmd":"orderpending/trade"}]}
# sell-buy: 1.2375 18.6
# sleep: 47s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12375 st 35 12376.0 12349.000000000002
# res_before 12305 -2 35
# res_after 12350.000000000002
# ============price================ 1.235
# vol=========   16
# {"result":[{"result":"12420083584410183","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584410194","cmd":"orderpending/trade"}]}
# sell-buy: 1.235 16
# sleep: 43s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12350 st 40 12376.0 12349.000000000002
# res_before 12310 -1 40
# res_after 12350.000000000002
# ============price================ 1.235
# vol=========   20
# {"result":[{"result":"12420083584414151","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584414157","cmd":"orderpending/trade"}]}
# sell-buy: 1.235 20
# sleep: 36s
# ask1 1.2376 bid1 1.2349 avol1 2025.6004 bvol1 449.066
# pr before 12350 st 45 12376.0 12349.000000000002
# res_before 12350 0 45
# res_after 12350.000000000002
# ============price================ 1.235
# vol=========   15.8
# {"result":[{"result":"12420083584417452","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584417464","cmd":"orderpending/trade"}]}
# buy-sell: 1.235 15.8
# sleep: 34s
# ask1 1.2376 bid1 1.2037 avol1 2025.6004 bvol1 204.1859
# pr before 12350 st 10 12376.0 12037.0
# res_before 12350 0 10
# res_after 12350
# ============price================ 1.235
# vol=========   16
# {"result":[{"result":"12420083584420705","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584420725","cmd":"orderpending/trade"}]}
# sell-buy: 1.235 16
# sleep: 30s
# ask1 1.2376 bid1 1.2037 avol1 2025.6004 bvol1 204.1859
# pr before 12350 st 25 12376.0 12037.0
# res_before 12375 1 25
# res_after 12375.0
# ============price================ 1.2375
# vol=========   15
# {"result":[{"result":"12420083584423850","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584423858","cmd":"orderpending/trade"}]}
# sell-buy: 1.2375 15
# sleep: 42s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12375 st 45 12376.0 12037.0
# res_before 12465 2 45
# res_after 12375.0
# ============price================ 1.2375
# vol=========   19.8
# {"result":[{"result":"12420083584428424","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584428441","cmd":"orderpending/trade"}]}
# sell-buy: 1.2375 19.8
# sleep: 22s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12375 st 10 12376.0 12037.0
# res_before 12365 -1 10
# res_after 12365
# ============price================ 1.2365
# vol=========   10
# {"result":[{"result":"12420083584430963","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584430973","cmd":"orderpending/trade"}]}
# sell-buy: 1.2365 10
# sleep: 32s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12365 st 35 12376.0 12037.0
# res_before 12435 2 35
# res_after 12375.0
# ============price================ 1.2375
# vol=========   20
# {"result":[{"result":"12420083584434524","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584434535","cmd":"orderpending/trade"}]}
# buy-sell: 1.2375 20
# sleep: 82s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12375 st 35 12376.0 12037.0
# res_before 12340 -1 35
# res_after 12340
# ============price================ 1.234
# vol=========   14.3
# {"result":[{"result":"12420083584442725","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584442732","cmd":"orderpending/trade"}]}
# buy-sell: 1.234 14.3
# sleep: 61s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12340 st 25 12376.0 12037.0
# res_before 12290 -2 25
# res_after 12290
# ============price================ 1.229
# vol=========   15
# {"result":[{"result":"12420083584448827","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584448836","cmd":"orderpending/trade"}]}
# buy-sell: 1.229 15
# sleep: 46s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12290 st 50 12376.0 12037.0
# res_before 12290 0 50
# res_after 12290
# ============price================ 1.229
# vol=========   10.4
# {"result":[{"result":"12420083584453595","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584453599","cmd":"orderpending/trade"}]}
# sell-buy: 1.229 10.4
# sleep: 50s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12290 st 10 12376.0 12037.0
# res_before 12290 0 10
# res_after 12290
# ============price================ 1.229
# vol=========   13.2
# {"result":[{"result":"12420083584458769","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584458779","cmd":"orderpending/trade"}]}
# sell-buy: 1.229 13.2
# sleep: 33s
# ask1 1.2376 bid1 1.2037 avol1 1513.5018 bvol1 204.1859
# pr before 12290 st 25 12376.0 12037.0
# res_before 12340 2 25
# res_after 12340
# ============price================ 1.234
# vol=========   13.02
# {"result":[{"result":"12420083584462236","cmd":"orderpending/trade"}]}
# {"result":[{"result":"12420083584462252","cmd":"orderpending/trade"}]}
# buy-sell: 1.234 13.02
# sleep: 30s

# %%
print (1)
# Out:
# 1
