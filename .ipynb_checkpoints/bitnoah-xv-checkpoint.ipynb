# %%
import requests
import hashlib
import random
import time

data = {
    'cid': "1",
    'funcid': "1",            # BTC_ETH
    'userid': '322276',    # 限价交易
    'phone': "15728090310",       # BUY SELL
    'passwd': hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest(),
    'coin': "XPV_USDT"
}


sign_str = "1"+"XPV_USDT"+"1"+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"15728090310"+"332031"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()

url = "http://www.wlex.me/intf/v2.jsp?"+"cid=1&"+"coin=XPV_USDT&"+"funcid=1&"+"phone=15728090310&"+\
"passwd="+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=332031"
r = requests.get(url)
res = r.text
rese = eval(res)
print (rese)
ask1 = float(rese['sales'][0]['price'])
bid1 = float(rese['buys'][0]['price'])
print ("ask1",ask1,"bid1",bid1)


def sell(price_buy,vol_buy):
    sign_str = "S1"+"XPV_USDT"+"2"+str(vol_buy)+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"15728090310"+str(price_buy)+"332031"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "http://www.wlex.me/intf/v2.jsp?"+"cid=1&"+"coin=XPV_USDT&"+"funcid=2&"+"phone=15728090310"+"&"+"passwd="+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=332031"+"&price="+str(price_buy)+"&num="+str(vol_buy)+"&bs=S"
    r = requests.get(url)
    res = r.text.replace("\n","")
    print (res)
    
    
def buy(price_buy,vol_buy):
    sign_str = "B1"+"XPV_USDT"+"2"+str(vol_buy)+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"15728090310"+str(price_buy)+"332031"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "http://www.wlex.me/intf/v2.jsp?"+"cid=1&"+"coin=XPV_USDT&"+"funcid=2&"+"phone=15728090310"+"&"+"passwd="+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=332031"+"&price="+str(price_buy)+"&num="+str(vol_buy)+"&bs=B"
    r = requests.get(url)
    res = r.text.replace("\n","")
    print (res)
      
#buy(0.13, 20)

# %%
sell(0.0293,24118.32)
buy(0.0293,24211.32)
# Out:
# {"status":"1","msg":"ok","orderid":"577135021"}
# {"status":"1","msg":"ok","orderid":"577135026"}

# %%
print (1)
# Out:
# 1

# %%
# coding: utf-8
#至于cancel，首先需要布密足够多的单子，使用手动布单
#其次，把所有bid2和ask2之后的单子，选一个挂撤



import requests
import hashlib
import random
import time

def sell(price_buy,vol_buy):
    sign_str = "S1"+"XPV_USDT"+"2"+str(vol_buy)+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"15728090310"+str(price_buy)+"332031"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "http://www.wlex.me/intf/v2.jsp?"+"cid=1&"+"coin=XPV_USDT&"+"funcid=2&"+"phone=15728090310"+"&"+"passwd="+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=332031"+"&price="+str(price_buy)+"&num="+str(vol_buy)+"&bs=S"
    r = requests.get(url)
    res = r.text.replace("\n","")
    
    
def buy(price_buy,vol_buy):
    sign_str = "B1"+"XPV_USDT"+"2"+str(vol_buy)+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"15728090310"+str(price_buy)+"332031"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "http://www.wlex.me/intf/v2.jsp?"+"cid=1&"+"coin=XPV_USDT&"+"funcid=2&"+"phone=15728090310"+"&"+"passwd="+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=332031"+"&price="+str(price_buy)+"&num="+str(vol_buy)+"&bs=B"
    r = requests.get(url)
    res = r.text.replace("\n","")

    
data = {
    'cid': "1",
    'funcid': "1",            # BTC_ETH
    'userid': '322276',    # 限价交易
    'phone': "15728090310",       # BUY SELL
    'passwd': hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest(),
    'coin': "XPV_USDT"
}


sign_str = "1"+"XPV_USDT"+"1"+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"15728090310"+"332031"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()

count = 0
price = 0

def combine(pr,st,b1,a1):
    print ("pr before",pr,"st",st,a1,b1)
    bei = random.randint(-2, 2) 
    res = pr+st*bei
    print ("res_before",res,bei,st)
    st1 = 1
    if res>=(a1-st1):
        res = a1-st1
    if res<=(b1+st1):
        res = b1 + st1
    #print ("bei",bei,"res",res)
    print ("res_after",res)
    return int(res)    

while True:
    slee1 = random.randint(30,50)
    slee2 = random.randint(10,30)
    slee3 = random.randint(9,10)
    slee = random.choice([slee1,slee2,slee3])
    print ("sleep: "+str(slee)+"s")
    time.sleep(slee)
    count = count + 1
    url = "http://www.wlex.me/intf/v2.jsp?"+"cid=1&"+"coin=XPV_USDT&"+"funcid=1&"+"phone=15728090310&"+\
    "passwd="+hashlib.md5("0310zhangzh".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=332031"
    r = requests.get(url)
    res = r.text
    rese = eval(res)
    #print (rese)
    ask1 = float(rese['sales'][0]['price'])
    bid1 = float(rese['buys'][0]['price'])
    print ("ask1",ask1,"bid1",bid1)
    if count %1==0:
        if ask1*1e5-bid1*1e5>=10:
            if price ==0:
                price = str(int((ask1*1e5+bid1*1e5)/2)*1.0/1e5)
            else:
                step = random.randint(0,3)
                deltaP = combine(int(float(price)*1e5),step,bid1*1e5,ask1*1e5)
                price = deltaP/1e5
            print ("============price================",price)
            dot = random.randint(1,10)
            if dot in [1,2,3,4]:
                vol = random.randint(150,500)
            elif dot in [5,6,7]:
                vol = random.randint(150,500) + random.randint(1,10)*1000/10000.0
            elif dot in [8,9]:
                vol = random.randint(150,500) + random.randint(1,100)*100/10000.0
            else:
                vol = random.randint(150,500) + random.randint(1,1000)*10/10000.0
            print ("vol=========  ",vol)
            #print ("make orders, price", price)
            dir_flag = random.randint(0,1)
            if dir_flag==0:
                buy(price,vol)
                sell(price,vol)    
                print ("buy-sell:",price,vol)
            else:
                sell(price,vol) 
                buy(price,vol)
                print ("sell-buy:",price,vol)
# Out:
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# ============price================ 0.04997
# vol=========   163.6
# buy-sell: 0.04997 163.6
# sleep: 38s
# ask1 0.0504 bid1 0.04955
# pr before 4997 st 3 5040.0 4955.0
# res_before 4994 -1 3
# res_after 4994
# ============price================ 0.04994
# vol=========   405
# buy-sell: 0.04994 405
# sleep: 18s
# ask1 0.0504 bid1 0.04955
# pr before 4994 st 2 5040.0 4955.0
# res_before 4994 0 2
# res_after 4994
# ============price================ 0.04994
# vol=========   411
# sell-buy: 0.04994 411
# sleep: 27s
# ask1 0.0504 bid1 0.04955
# pr before 4994 st 1 5040.0 4955.0
# res_before 4993 -1 1
# res_after 4993
# ============price================ 0.04993
# vol=========   344
# sell-buy: 0.04993 344
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 4993 st 0 5040.0 4955.0
# res_before 4993 2 0
# res_after 4993
# ============price================ 0.04993
# vol=========   194.8
# buy-sell: 0.04993 194.8
# sleep: 34s
# ask1 0.0504 bid1 0.04955
# pr before 4993 st 3 5040.0 4955.0
# res_before 4996 1 3
# res_after 4996
# ============price================ 0.04996
# vol=========   207.44
# buy-sell: 0.04996 207.44
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 4996 st 3 5040.0 4955.0
# res_before 5002 2 3
# res_after 5002
# ============price================ 0.05002
# vol=========   477.0
# sell-buy: 0.05002 477.0
# sleep: 18s
# ask1 0.0504 bid1 0.04955
# pr before 5002 st 1 5040.0 4955.0
# res_before 5001 -1 1
# res_after 5001
# ============price================ 0.05001
# vol=========   250
# buy-sell: 0.05001 250
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5001 st 0 5040.0 4955.0
# res_before 5001 -1 0
# res_after 5001
# ============price================ 0.05001
# vol=========   212
# buy-sell: 0.05001 212
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5001 st 0 5040.0 4955.0
# res_before 5001 -1 0
# res_after 5001
# ============price================ 0.05001
# vol=========   285.6
# buy-sell: 0.05001 285.6
# sleep: 26s
# ask1 0.0504 bid1 0.04955
# pr before 5001 st 2 5040.0 4955.0
# res_before 4997 -2 2
# res_after 4997
# ============price================ 0.04997
# vol=========   393
# sell-buy: 0.04997 393
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 4997 st 0 5040.0 4955.0
# res_before 4997 -2 0
# res_after 4997
# ============price================ 0.04997
# vol=========   408
# sell-buy: 0.04997 408
# sleep: 34s
# ask1 0.0504 bid1 0.04955
# pr before 4997 st 3 5040.0 4955.0
# res_before 4994 -1 3
# res_after 4994
# ============price================ 0.04994
# vol=========   353
# sell-buy: 0.04994 353
# sleep: 48s
# ask1 0.0504 bid1 0.04955
# pr before 4994 st 2 5040.0 4955.0
# res_before 4994 0 2
# res_after 4994
# ============price================ 0.04994
# vol=========   234.3
# sell-buy: 0.04994 234.3
# sleep: 47s
# ask1 0.0504 bid1 0.04955
# pr before 4994 st 3 5040.0 4955.0
# res_before 5000 2 3
# res_after 5000
# ============price================ 0.05
# vol=========   478
# sell-buy: 0.05 478
# sleep: 19s
# ask1 0.0504 bid1 0.04955
# pr before 5000 st 1 5040.0 4955.0
# res_before 4999 -1 1
# res_after 4999
# ============price================ 0.04999
# vol=========   472.5
# buy-sell: 0.04999 472.5
# sleep: 38s
# ask1 0.0504 bid1 0.04955
# pr before 4999 st 3 5040.0 4955.0
# res_before 5005 2 3
# res_after 5005
# ============price================ 0.05005
# vol=========   215.8
# buy-sell: 0.05005 215.8
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 3 5040.0 4955.0
# res_before 5008 1 3
# res_after 5008
# ============price================ 0.05008
# vol=========   239
# sell-buy: 0.05008 239
# sleep: 20s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 3 5040.0 4955.0
# res_before 5002 -2 3
# res_after 5002
# ============price================ 0.05002
# vol=========   472.54
# sell-buy: 0.05002 472.54
# sleep: 35s
# ask1 0.0504 bid1 0.04955
# pr before 5002 st 0 5040.0 4955.0
# res_before 5002 1 0
# res_after 5002
# ============price================ 0.05002
# vol=========   198.6
# sell-buy: 0.05002 198.6
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5002 st 0 5040.0 4955.0
# res_before 5002 -1 0
# res_after 5002
# ============price================ 0.05002
# vol=========   384
# buy-sell: 0.05002 384
# sleep: 42s
# ask1 0.0504 bid1 0.04955
# pr before 5002 st 3 5040.0 4955.0
# res_before 5005 1 3
# res_after 5005
# ============price================ 0.05005
# vol=========   164.5
# buy-sell: 0.05005 164.5
# sleep: 41s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 0 5040.0 4955.0
# res_before 5005 0 0
# res_after 5005
# ============price================ 0.05005
# vol=========   557.3
# sell-buy: 0.05005 557.3
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 0 5040.0 4955.0
# res_before 5005 2 0
# res_after 5005
# ============price================ 0.05005
# vol=========   257
# buy-sell: 0.05005 257
# sleep: 14s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 3 5040.0 4955.0
# res_before 4999 -2 3
# res_after 4999
# ============price================ 0.04999
# vol=========   328.76
# buy-sell: 0.04999 328.76
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 4999 st 1 5040.0 4955.0
# res_before 5000 1 1
# res_after 5000
# ============price================ 0.05
# vol=========   332
# buy-sell: 0.05 332
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5000 st 0 5040.0 4955.0
# res_before 5000 0 0
# res_after 5000
# ============price================ 0.05
# vol=========   239.26
# buy-sell: 0.05 239.26
# sleep: 14s
# ask1 0.0504 bid1 0.04955
# pr before 5000 st 3 5040.0 4955.0
# res_before 5006 2 3
# res_after 5006
# ============price================ 0.05006
# vol=========   236.0
# buy-sell: 0.05006 236.0
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 0 5040.0 4955.0
# res_before 5006 1 0
# res_after 5006
# ============price================ 0.05006
# vol=========   495
# buy-sell: 0.05006 495
# sleep: 11s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 0 5040.0 4955.0
# res_before 5006 2 0
# res_after 5006
# ============price================ 0.05006
# vol=========   364
# sell-buy: 0.05006 364
# sleep: 29s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 0 5040.0 4955.0
# res_before 5006 1 0
# res_after 5006
# ============price================ 0.05006
# vol=========   213
# buy-sell: 0.05006 213
# sleep: 29s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 3 5040.0 4955.0
# res_before 5006 0 3
# res_after 5006
# ============price================ 0.05006
# vol=========   487
# sell-buy: 0.05006 487
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 3 5040.0 4955.0
# res_before 5012 2 3
# res_after 5012
# ============price================ 0.05012
# vol=========   329
# buy-sell: 0.05012 329
# sleep: 46s
# ask1 0.0504 bid1 0.04955
# pr before 5012 st 0 5040.0 4955.0
# res_before 5012 0 0
# res_after 5012
# ============price================ 0.05012
# vol=========   310.4
# buy-sell: 0.05012 310.4
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5012 st 0 5040.0 4955.0
# res_before 5012 -1 0
# res_after 5012
# ============price================ 0.05012
# vol=========   486
# buy-sell: 0.05012 486
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5012 st 3 5040.0 4955.0
# res_before 5015 1 3
# res_after 5015
# ============price================ 0.05015
# vol=========   560.7
# sell-buy: 0.05015 560.7
# sleep: 19s
# ask1 0.0504 bid1 0.04955
# pr before 5015 st 1 5040.0 4955.0
# res_before 5014 -1 1
# res_after 5014
# ============price================ 0.05014
# vol=========   249
# buy-sell: 0.05014 249
# sleep: 12s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 3 5040.0 4955.0
# res_before 5008 -2 3
# res_after 5008
# ============price================ 0.05008
# vol=========   409.55
# buy-sell: 0.05008 409.55
# sleep: 12s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 1 5040.0 4955.0
# res_before 5009 1 1
# res_after 5009
# ============price================ 0.05009
# vol=========   478.36
# sell-buy: 0.05009 478.36
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 0 5040.0 4955.0
# res_before 5009 0 0
# res_after 5009
# ============price================ 0.05009
# vol=========   284.38
# sell-buy: 0.05009 284.38
# sleep: 17s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 2 5040.0 4955.0
# res_before 5005 -2 2
# res_after 5005
# ============price================ 0.05005
# vol=========   401.66
# sell-buy: 0.05005 401.66
# sleep: 29s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 0 5040.0 4955.0
# res_before 5005 2 0
# res_after 5005
# ============price================ 0.05005
# vol=========   330
# sell-buy: 0.05005 330
# sleep: 18s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 0 5040.0 4955.0
# res_before 5005 2 0
# res_after 5005
# ============price================ 0.05005
# vol=========   379.6
# buy-sell: 0.05005 379.6
# sleep: 17s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 1 5040.0 4955.0
# res_before 5003 -2 1
# res_after 5003
# ============price================ 0.05003
# vol=========   331
# sell-buy: 0.05003 331
# sleep: 26s
# ask1 0.0504 bid1 0.04955
# pr before 5003 st 1 5040.0 4955.0
# res_before 5003 0 1
# res_after 5003
# ============price================ 0.05003
# vol=========   543.2
# buy-sell: 0.05003 543.2
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5003 st 3 5040.0 4955.0
# res_before 5003 0 3
# res_after 5003
# ============price================ 0.05003
# vol=========   303.3
# sell-buy: 0.05003 303.3
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5003 st 3 5040.0 4955.0
# res_before 5006 1 3
# res_after 5006
# ============price================ 0.05006
# vol=========   556.5
# buy-sell: 0.05006 556.5
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 0 5040.0 4955.0
# res_before 5006 2 0
# res_after 5006
# ============price================ 0.05006
# vol=========   343
# sell-buy: 0.05006 343
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 2 5040.0 4955.0
# res_before 5010 2 2
# res_after 5010
# ============price================ 0.0501
# vol=========   365.1
# sell-buy: 0.0501 365.1
# sleep: 27s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 3 5040.0 4955.0
# res_before 5013 1 3
# res_after 5013
# ============price================ 0.05013
# vol=========   401
# buy-sell: 0.05013 401
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 2 5040.0 4955.0
# res_before 5009 -2 2
# res_after 5009
# ============price================ 0.05009
# vol=========   405.0
# sell-buy: 0.05009 405.0
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 2 5040.0 4955.0
# res_before 5009 0 2
# res_after 5009
# ============price================ 0.05009
# vol=========   349.3
# buy-sell: 0.05009 349.3
# sleep: 16s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 1 5040.0 4955.0
# res_before 5010 1 1
# res_after 5010
# ============price================ 0.0501
# vol=========   490.7
# buy-sell: 0.0501 490.7
# sleep: 35s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 0 5040.0 4955.0
# res_before 5010 0 0
# res_after 5010
# ============price================ 0.0501
# vol=========   223.3
# buy-sell: 0.0501 223.3
# sleep: 14s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 3 5040.0 4955.0
# res_before 5007 -1 3
# res_after 5007
# ============price================ 0.05007
# vol=========   478.3
# buy-sell: 0.05007 478.3
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 1 5040.0 4955.0
# res_before 5008 1 1
# res_after 5008
# ============price================ 0.05008
# vol=========   399.8
# sell-buy: 0.05008 399.8
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 1 5040.0 4955.0
# res_before 5009 1 1
# res_after 5009
# ============price================ 0.05009
# vol=========   401.02
# sell-buy: 0.05009 401.02
# sleep: 40s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 1 5040.0 4955.0
# res_before 5009 0 1
# res_after 5009
# ============price================ 0.05009
# vol=========   495.3
# buy-sell: 0.05009 495.3
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 2 5040.0 4955.0
# res_before 5007 -1 2
# res_after 5007
# ============price================ 0.05007
# vol=========   329.7
# buy-sell: 0.05007 329.7
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 0 5040.0 4955.0
# res_before 5007 0 0
# res_after 5007
# ============price================ 0.05007
# vol=========   477
# sell-buy: 0.05007 477
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 1 5040.0 4955.0
# res_before 5009 2 1
# res_after 5009
# ============price================ 0.05009
# vol=========   343
# sell-buy: 0.05009 343
# sleep: 24s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 2 5040.0 4955.0
# res_before 5005 -2 2
# res_after 5005
# ============price================ 0.05005
# vol=========   330.8
# buy-sell: 0.05005 330.8
# sleep: 27s
# ask1 0.0504 bid1 0.04955
# pr before 5005 st 1 5040.0 4955.0
# res_before 5006 1 1
# res_after 5006
# ============price================ 0.05006
# vol=========   484.6
# sell-buy: 0.05006 484.6
# sleep: 39s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 2 5040.0 4955.0
# res_before 5010 2 2
# res_after 5010
# ============price================ 0.0501
# vol=========   379.5
# buy-sell: 0.0501 379.5
# sleep: 43s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 1 5040.0 4955.0
# res_before 5008 -2 1
# res_after 5008
# ============price================ 0.05008
# vol=========   375
# buy-sell: 0.05008 375
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 2 5040.0 4955.0
# res_before 5008 0 2
# res_after 5008
# ============price================ 0.05008
# vol=========   399
# sell-buy: 0.05008 399
# sleep: 49s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 0 5040.0 4955.0
# res_before 5008 2 0
# res_after 5008
# ============price================ 0.05008
# vol=========   432.8
# buy-sell: 0.05008 432.8
# sleep: 19s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 0 5040.0 4955.0
# res_before 5008 -1 0
# res_after 5008
# ============price================ 0.05008
# vol=========   462.4
# buy-sell: 0.05008 462.4
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 0 5040.0 4955.0
# res_before 5008 2 0
# res_after 5008
# ============price================ 0.05008
# vol=========   263.4
# buy-sell: 0.05008 263.4
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 3 5040.0 4955.0
# res_before 5008 0 3
# res_after 5008
# ============price================ 0.05008
# vol=========   443.6
# sell-buy: 0.05008 443.6
# sleep: 19s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 2 5040.0 4955.0
# res_before 5008 0 2
# res_after 5008
# ============price================ 0.05008
# vol=========   438
# buy-sell: 0.05008 438
# sleep: 22s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 3 5040.0 4955.0
# res_before 5002 -2 3
# res_after 5002
# ============price================ 0.05002
# vol=========   150
# buy-sell: 0.05002 150
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5002 st 3 5040.0 4955.0
# res_before 5008 2 3
# res_after 5008
# ============price================ 0.05008
# vol=========   351.0
# buy-sell: 0.05008 351.0
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 1 5040.0 4955.0
# res_before 5009 1 1
# res_after 5009
# ============price================ 0.05009
# vol=========   486.51
# sell-buy: 0.05009 486.51
# sleep: 45s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 3 5040.0 4955.0
# res_before 5012 1 3
# res_after 5012
# ============price================ 0.05012
# vol=========   465
# sell-buy: 0.05012 465
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5012 st 2 5040.0 4955.0
# res_before 5012 0 2
# res_after 5012
# ============price================ 0.05012
# vol=========   204.04
# sell-buy: 0.05012 204.04
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5012 st 1 5040.0 4955.0
# res_before 5012 0 1
# res_after 5012
# ============price================ 0.05012
# vol=========   270.5
# buy-sell: 0.05012 270.5
# sleep: 22s
# ask1 0.0504 bid1 0.04955
# pr before 5012 st 3 5040.0 4955.0
# res_before 5018 2 3
# res_after 5018
# ============price================ 0.05018
# vol=========   439.5
# buy-sell: 0.05018 439.5
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5018 st 3 5040.0 4955.0
# res_before 5015 -1 3
# res_after 5015
# ============price================ 0.05015
# vol=========   297
# buy-sell: 0.05015 297
# sleep: 43s
# ask1 0.0504 bid1 0.04955
# pr before 5015 st 2 5040.0 4955.0
# res_before 5017 1 2
# res_after 5017
# ============price================ 0.05017
# vol=========   310.9
# sell-buy: 0.05017 310.9
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5017 st 3 5040.0 4955.0
# res_before 5023 2 3
# res_after 5023
# ============price================ 0.05023
# vol=========   410.4
# buy-sell: 0.05023 410.4
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 1 5040.0 4955.0
# res_before 5023 0 1
# res_after 5023
# ============price================ 0.05023
# vol=========   199
# sell-buy: 0.05023 199
# sleep: 38s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 1 5040.0 4955.0
# res_before 5024 1 1
# res_after 5024
# ============price================ 0.05024
# vol=========   525.2
# buy-sell: 0.05024 525.2
# sleep: 18s
# ask1 0.0504 bid1 0.04955
# pr before 5024 st 2 5040.0 4955.0
# res_before 5020 -2 2
# res_after 5020
# ============price================ 0.0502
# vol=========   428.2
# sell-buy: 0.0502 428.2
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5020 st 1 5040.0 4955.0
# res_before 5021 1 1
# res_after 5021
# ============price================ 0.05021
# vol=========   186.1
# sell-buy: 0.05021 186.1
# sleep: 48s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 1 5040.0 4955.0
# res_before 5023 2 1
# res_after 5023
# ============price================ 0.05023
# vol=========   386.6
# buy-sell: 0.05023 386.6
# sleep: 35s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 2 5040.0 4955.0
# res_before 5021 -1 2
# res_after 5021
# ============price================ 0.05021
# vol=========   235.22
# sell-buy: 0.05021 235.22
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 1 5040.0 4955.0
# res_before 5022 1 1
# res_after 5022
# ============price================ 0.05022
# vol=========   190.1
# sell-buy: 0.05022 190.1
# sleep: 36s
# ask1 0.0504 bid1 0.04955
# pr before 5022 st 3 5040.0 4955.0
# res_before 5025 1 3
# res_after 5025
# ============price================ 0.05025
# vol=========   395.47
# sell-buy: 0.05025 395.47
# sleep: 45s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 2 5040.0 4955.0
# res_before 5025 0 2
# res_after 5025
# ============price================ 0.05025
# vol=========   449
# sell-buy: 0.05025 449
# sleep: 23s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 3 5040.0 4955.0
# res_before 5019 -2 3
# res_after 5019
# ============price================ 0.05019
# vol=========   368.95
# sell-buy: 0.05019 368.95
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 3 5040.0 4955.0
# res_before 5016 -1 3
# res_after 5016
# ============price================ 0.05016
# vol=========   226.95
# buy-sell: 0.05016 226.95
# sleep: 11s
# ask1 0.0504 bid1 0.04955
# pr before 5016 st 3 5040.0 4955.0
# res_before 5019 1 3
# res_after 5019
# ============price================ 0.05019
# vol=========   454
# sell-buy: 0.05019 454
# sleep: 39s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 2 5040.0 4955.0
# res_before 5023 2 2
# res_after 5023
# ============price================ 0.05023
# vol=========   296.0
# buy-sell: 0.05023 296.0
# sleep: 15s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 0 5040.0 4955.0
# res_before 5023 1 0
# res_after 5023
# ============price================ 0.05023
# vol=========   221
# buy-sell: 0.05023 221
# sleep: 49s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 3 5040.0 4955.0
# res_before 5026 1 3
# res_after 5026
# ============price================ 0.05026
# vol=========   471
# sell-buy: 0.05026 471
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 0 5040.0 4955.0
# res_before 5026 -2 0
# res_after 5026
# ============price================ 0.05026
# vol=========   339
# sell-buy: 0.05026 339
# sleep: 45s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 3 5040.0 4955.0
# res_before 5020 -2 3
# res_after 5020
# ============price================ 0.0502
# vol=========   431
# sell-buy: 0.0502 431
# sleep: 49s
# ask1 0.0504 bid1 0.04955
# pr before 5020 st 2 5040.0 4955.0
# res_before 5024 2 2
# res_after 5024
# ============price================ 0.05024
# vol=========   210.8
# buy-sell: 0.05024 210.8
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5024 st 1 5040.0 4955.0
# res_before 5023 -1 1
# res_after 5023
# ============price================ 0.05023
# vol=========   467.9
# sell-buy: 0.05023 467.9
# sleep: 23s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 2 5040.0 4955.0
# res_before 5027 2 2
# res_after 5027
# ============price================ 0.05027
# vol=========   384
# sell-buy: 0.05027 384
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5027 st 2 5040.0 4955.0
# res_before 5029 1 2
# res_after 5029
# ============price================ 0.05029
# vol=========   165
# sell-buy: 0.05029 165
# sleep: 22s
# ask1 0.0504 bid1 0.04955
# pr before 5029 st 3 5040.0 4955.0
# res_before 5029 0 3
# res_after 5029
# ============price================ 0.05029
# vol=========   161
# buy-sell: 0.05029 161
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5029 st 3 5040.0 4955.0
# res_before 5023 -2 3
# res_after 5023
# ============price================ 0.05023
# vol=========   153
# buy-sell: 0.05023 153
# sleep: 31s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 1 5040.0 4955.0
# res_before 5025 2 1
# res_after 5025
# ============price================ 0.05025
# vol=========   245.2
# sell-buy: 0.05025 245.2
# sleep: 49s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 3 5040.0 4955.0
# res_before 5025 0 3
# res_after 5025
# ============price================ 0.05025
# vol=========   373
# sell-buy: 0.05025 373
# sleep: 25s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 0 5040.0 4955.0
# res_before 5025 1 0
# res_after 5025
# ============price================ 0.05025
# vol=========   462.4
# sell-buy: 0.05025 462.4
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 3 5040.0 4955.0
# res_before 5022 -1 3
# res_after 5022
# ============price================ 0.05022
# vol=========   274.11
# sell-buy: 0.05022 274.11
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5022 st 2 5040.0 4955.0
# res_before 5024 1 2
# res_after 5024
# ============price================ 0.05024
# vol=========   403.1
# sell-buy: 0.05024 403.1
# sleep: 13s
# ask1 0.0504 bid1 0.04955
# pr before 5024 st 3 5040.0 4955.0
# res_before 5021 -1 3
# res_after 5021
# ============price================ 0.05021
# vol=========   447
# sell-buy: 0.05021 447
# sleep: 33s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 2 5040.0 4955.0
# res_before 5019 -1 2
# res_after 5019
# ============price================ 0.05019
# vol=========   471
# buy-sell: 0.05019 471
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 3 5040.0 4955.0
# res_before 5022 1 3
# res_after 5022
# ============price================ 0.05022
# vol=========   196
# sell-buy: 0.05022 196
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5022 st 1 5040.0 4955.0
# res_before 5023 1 1
# res_after 5023
# ============price================ 0.05023
# vol=========   394.27
# buy-sell: 0.05023 394.27
# sleep: 28s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 1 5040.0 4955.0
# res_before 5025 2 1
# res_after 5025
# ============price================ 0.05025
# vol=========   384
# sell-buy: 0.05025 384
# sleep: 31s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 2 5040.0 4955.0
# res_before 5021 -2 2
# res_after 5021
# ============price================ 0.05021
# vol=========   308
# buy-sell: 0.05021 308
# sleep: 40s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 1 5040.0 4955.0
# res_before 5021 0 1
# res_after 5021
# ============price================ 0.05021
# vol=========   269.5
# sell-buy: 0.05021 269.5
# sleep: 24s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 2 5040.0 4955.0
# res_before 5021 0 2
# res_after 5021
# ============price================ 0.05021
# vol=========   258.85
# buy-sell: 0.05021 258.85
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 3 5040.0 4955.0
# res_before 5021 0 3
# res_after 5021
# ============price================ 0.05021
# vol=========   481.3
# sell-buy: 0.05021 481.3
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 3 5040.0 4955.0
# res_before 5018 -1 3
# res_after 5018
# ============price================ 0.05018
# vol=========   455.69
# buy-sell: 0.05018 455.69
# sleep: 24s
# ask1 0.0504 bid1 0.04955
# pr before 5018 st 0 5040.0 4955.0
# res_before 5018 1 0
# res_after 5018
# ============price================ 0.05018
# vol=========   171
# sell-buy: 0.05018 171
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5018 st 2 5040.0 4955.0
# res_before 5014 -2 2
# res_after 5014
# ============price================ 0.05014
# vol=========   315.9
# buy-sell: 0.05014 315.9
# sleep: 43s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 0 5040.0 4955.0
# res_before 5014 0 0
# res_after 5014
# ============price================ 0.05014
# vol=========   351
# sell-buy: 0.05014 351
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 3 5040.0 4955.0
# res_before 5008 -2 3
# res_after 5008
# ============price================ 0.05008
# vol=========   324
# sell-buy: 0.05008 324
# sleep: 36s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 3 5040.0 4955.0
# res_before 5014 2 3
# res_after 5014
# ============price================ 0.05014
# vol=========   166.5
# sell-buy: 0.05014 166.5
# sleep: 17s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 3 5040.0 4955.0
# res_before 5020 2 3
# res_after 5020
# ============price================ 0.0502
# vol=========   446
# sell-buy: 0.0502 446
# sleep: 38s
# ask1 0.0504 bid1 0.04955
# pr before 5020 st 1 5040.0 4955.0
# res_before 5019 -1 1
# res_after 5019
# ============price================ 0.05019
# vol=========   257
# buy-sell: 0.05019 257
# sleep: 17s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 2 5040.0 4955.0
# res_before 5023 2 2
# res_after 5023
# ============price================ 0.05023
# vol=========   235.4
# buy-sell: 0.05023 235.4
# sleep: 33s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 2 5040.0 4955.0
# res_before 5025 1 2
# res_after 5025
# ============price================ 0.05025
# vol=========   304
# sell-buy: 0.05025 304
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 2 5040.0 4955.0
# res_before 5021 -2 2
# res_after 5021
# ============price================ 0.05021
# vol=========   263.47
# buy-sell: 0.05021 263.47
# sleep: 33s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 1 5040.0 4955.0
# res_before 5019 -2 1
# res_after 5019
# ============price================ 0.05019
# vol=========   219.6
# buy-sell: 0.05019 219.6
# sleep: 44s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 3 5040.0 4955.0
# res_before 5013 -2 3
# res_after 5013
# ============price================ 0.05013
# vol=========   152
# buy-sell: 0.05013 152
# sleep: 33s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 1 5040.0 4955.0
# res_before 5013 0 1
# res_after 5013
# ============price================ 0.05013
# vol=========   356.34
# buy-sell: 0.05013 356.34
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 0 5040.0 4955.0
# res_before 5013 0 0
# res_after 5013
# ============price================ 0.05013
# vol=========   315.8
# sell-buy: 0.05013 315.8
# sleep: 40s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 3 5040.0 4955.0
# res_before 5010 -1 3
# res_after 5010
# ============price================ 0.0501
# vol=========   230.1
# sell-buy: 0.0501 230.1
# sleep: 34s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 3 5040.0 4955.0
# res_before 5007 -1 3
# res_after 5007
# ============price================ 0.05007
# vol=========   416.42
# sell-buy: 0.05007 416.42
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 0 5040.0 4955.0
# res_before 5007 1 0
# res_after 5007
# ============price================ 0.05007
# vol=========   415.2
# buy-sell: 0.05007 415.2
# sleep: 34s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 0 5040.0 4955.0
# res_before 5007 -2 0
# res_after 5007
# ============price================ 0.05007
# vol=========   299.08
# buy-sell: 0.05007 299.08
# sleep: 36s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 3 5040.0 4955.0
# res_before 5007 0 3
# res_after 5007
# ============price================ 0.05007
# vol=========   199
# buy-sell: 0.05007 199
# sleep: 41s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 2 5040.0 4955.0
# res_before 5007 0 2
# res_after 5007
# ============price================ 0.05007
# vol=========   303.27
# sell-buy: 0.05007 303.27
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5007 st 2 5040.0 4955.0
# res_before 5011 2 2
# res_after 5011
# ============price================ 0.05011
# vol=========   160
# buy-sell: 0.05011 160
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5011 st 0 5040.0 4955.0
# res_before 5011 -1 0
# res_after 5011
# ============price================ 0.05011
# vol=========   185.8
# sell-buy: 0.05011 185.8
# sleep: 40s
# ask1 0.0504 bid1 0.04955
# pr before 5011 st 3 5040.0 4955.0
# res_before 5017 2 3
# res_after 5017
# ============price================ 0.05017
# vol=========   234.7
# sell-buy: 0.05017 234.7
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5017 st 0 5040.0 4955.0
# res_before 5017 -1 0
# res_after 5017
# ============price================ 0.05017
# vol=========   275
# buy-sell: 0.05017 275
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5017 st 1 5040.0 4955.0
# res_before 5017 0 1
# res_after 5017
# ============price================ 0.05017
# vol=========   454.7
# sell-buy: 0.05017 454.7
# sleep: 22s
# ask1 0.0504 bid1 0.04955
# pr before 5017 st 0 5040.0 4955.0
# res_before 5017 0 0
# res_after 5017
# ============price================ 0.05017
# vol=========   366.9
# buy-sell: 0.05017 366.9
# sleep: 45s
# ask1 0.0504 bid1 0.04955
# pr before 5017 st 0 5040.0 4955.0
# res_before 5017 -1 0
# res_after 5017
# ============price================ 0.05017
# vol=========   180
# buy-sell: 0.05017 180
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5017 st 2 5040.0 4955.0
# res_before 5017 0 2
# res_after 5017
# ============price================ 0.05017
# vol=========   459.16
# sell-buy: 0.05017 459.16
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5017 st 3 5040.0 4955.0
# res_before 5014 -1 3
# res_after 5014
# ============price================ 0.05014
# vol=========   249
# buy-sell: 0.05014 249
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 1 5040.0 4955.0
# res_before 5013 -1 1
# res_after 5013
# ============price================ 0.05013
# vol=========   196
# buy-sell: 0.05013 196
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 0 5040.0 4955.0
# res_before 5013 2 0
# res_after 5013
# ============price================ 0.05013
# vol=========   280.29
# sell-buy: 0.05013 280.29
# sleep: 12s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 1 5040.0 4955.0
# res_before 5014 1 1
# res_after 5014
# ============price================ 0.05014
# vol=========   209.6
# sell-buy: 0.05014 209.6
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 1 5040.0 4955.0
# res_before 5016 2 1
# res_after 5016
# ============price================ 0.05016
# vol=========   451
# sell-buy: 0.05016 451
# sleep: 41s
# ask1 0.0504 bid1 0.04955
# pr before 5016 st 0 5040.0 4955.0
# res_before 5016 1 0
# res_after 5016
# ============price================ 0.05016
# vol=========   369.4
# sell-buy: 0.05016 369.4
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5016 st 1 5040.0 4955.0
# res_before 5014 -2 1
# res_after 5014
# ============price================ 0.05014
# vol=========   245
# buy-sell: 0.05014 245
# sleep: 21s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 0 5040.0 4955.0
# res_before 5014 1 0
# res_after 5014
# ============price================ 0.05014
# vol=========   294
# sell-buy: 0.05014 294
# sleep: 50s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 1 5040.0 4955.0
# res_before 5013 -1 1
# res_after 5013
# ============price================ 0.05013
# vol=========   485
# buy-sell: 0.05013 485
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 0 5040.0 4955.0
# res_before 5013 2 0
# res_after 5013
# ============price================ 0.05013
# vol=========   270.3
# buy-sell: 0.05013 270.3
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 2 5040.0 4955.0
# res_before 5011 -1 2
# res_after 5011
# ============price================ 0.05011
# vol=========   239.0
# buy-sell: 0.05011 239.0
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5011 st 3 5040.0 4955.0
# res_before 5011 0 3
# res_after 5011
# ============price================ 0.05011
# vol=========   232.1
# buy-sell: 0.05011 232.1
# sleep: 35s
# ask1 0.0504 bid1 0.04955
# pr before 5011 st 2 5040.0 4955.0
# res_before 5011 0 2
# res_after 5011
# ============price================ 0.05011
# vol=========   280.4
# buy-sell: 0.05011 280.4
# sleep: 21s
# ask1 0.0504 bid1 0.04955
# pr before 5011 st 1 5040.0 4955.0
# res_before 5013 2 1
# res_after 5013
# ============price================ 0.05013
# vol=========   180
# sell-buy: 0.05013 180
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 0 5040.0 4955.0
# res_before 5013 2 0
# res_after 5013
# ============price================ 0.05013
# vol=========   452.2
# sell-buy: 0.05013 452.2
# sleep: 36s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 0 5040.0 4955.0
# res_before 5013 -1 0
# res_after 5013
# ============price================ 0.05013
# vol=========   338
# buy-sell: 0.05013 338
# sleep: 15s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 3 5040.0 4955.0
# res_before 5013 0 3
# res_after 5013
# ============price================ 0.05013
# vol=========   170
# buy-sell: 0.05013 170
# sleep: 31s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 2 5040.0 4955.0
# res_before 5009 -2 2
# res_after 5009
# ============price================ 0.05009
# vol=========   493
# buy-sell: 0.05009 493
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 1 5040.0 4955.0
# res_before 5011 2 1
# res_after 5011
# ============price================ 0.05011
# vol=========   273
# buy-sell: 0.05011 273
# sleep: 50s
# ask1 0.0504 bid1 0.04955
# pr before 5011 st 2 5040.0 4955.0
# res_before 5013 1 2
# res_after 5013
# ============price================ 0.05013
# vol=========   379.2
# sell-buy: 0.05013 379.2
# sleep: 24s
# ask1 0.0504 bid1 0.04955
# pr before 5013 st 0 5040.0 4955.0
# res_before 5013 2 0
# res_after 5013
# ============price================ 0.05013
# vol=========   384
# buy-sell: 0.05013 384
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 1 5040.0 4955.0
# res_before 5009 0 1
# res_after 5009
# ============price================ 0.05009
# vol=========   258
# buy-sell: 0.05009 258
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 3 5040.0 4955.0
# res_before 5015 2 3
# res_after 5015
# ============price================ 0.05015
# vol=========   271.1
# sell-buy: 0.05015 271.1
# sleep: 27s
# ask1 0.0504 bid1 0.04955
# pr before 5015 st 3 5040.0 4955.0
# res_before 5009 -2 3
# res_after 5009
# ============price================ 0.05009
# vol=========   415
# sell-buy: 0.05009 415
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 2 5040.0 4955.0
# res_before 5009 0 2
# res_after 5009
# ============price================ 0.05009
# vol=========   275
# sell-buy: 0.05009 275
# sleep: 48s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 0 5040.0 4955.0
# res_before 5009 0 0
# res_after 5009
# ============price================ 0.05009
# vol=========   365.0
# sell-buy: 0.05009 365.0
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5009 st 1 5040.0 4955.0
# res_before 5008 -1 1
# res_after 5008
# ============price================ 0.05008
# vol=========   405
# sell-buy: 0.05008 405
# sleep: 20s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 2 5040.0 4955.0
# res_before 5006 -1 2
# res_after 5006
# ============price================ 0.05006
# vol=========   399.8
# sell-buy: 0.05006 399.8
# sleep: 27s
# ask1 0.0504 bid1 0.04955
# pr before 5006 st 1 5040.0 4955.0
# res_before 5008 2 1
# res_after 5008
# ============price================ 0.05008
# vol=========   404
# buy-sell: 0.05008 404
# sleep: 29s
# ask1 0.0504 bid1 0.04955
# pr before 5008 st 2 5040.0 4955.0
# res_before 5012 2 2
# res_after 5012
# ============price================ 0.05012
# vol=========   490
# sell-buy: 0.05012 490
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5012 st 1 5040.0 4955.0
# res_before 5010 -2 1
# res_after 5010
# ============price================ 0.0501
# vol=========   273
# buy-sell: 0.0501 273
# sleep: 36s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 0 5040.0 4955.0
# res_before 5010 -2 0
# res_after 5010
# ============price================ 0.0501
# vol=========   307
# buy-sell: 0.0501 307
# sleep: 17s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 0 5040.0 4955.0
# res_before 5010 2 0
# res_after 5010
# ============price================ 0.0501
# vol=========   250
# buy-sell: 0.0501 250
# sleep: 31s
# ask1 0.0504 bid1 0.04955
# pr before 5010 st 2 5040.0 4955.0
# res_before 5014 2 2
# res_after 5014
# ============price================ 0.05014
# vol=========   440
# sell-buy: 0.05014 440
# sleep: 39s
# ask1 0.0504 bid1 0.04955
# pr before 5014 st 3 5040.0 4955.0
# res_before 5020 2 3
# res_after 5020
# ============price================ 0.0502
# vol=========   261.54
# sell-buy: 0.0502 261.54
# sleep: 42s
# ask1 0.0504 bid1 0.04955
# pr before 5020 st 2 5040.0 4955.0
# res_before 5024 2 2
# res_after 5024
# ============price================ 0.05024
# vol=========   176
# sell-buy: 0.05024 176
# sleep: 13s
# ask1 0.0504 bid1 0.04955
# pr before 5024 st 2 5040.0 4955.0
# res_before 5028 2 2
# res_after 5028
# ============price================ 0.05028
# vol=========   309.1
# buy-sell: 0.05028 309.1
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 3 5040.0 4955.0
# res_before 5022 -2 3
# res_after 5022
# ============price================ 0.05022
# vol=========   293.8
# buy-sell: 0.05022 293.8
# sleep: 35s
# ask1 0.0504 bid1 0.04955
# pr before 5022 st 1 5040.0 4955.0
# res_before 5021 -1 1
# res_after 5021
# ============price================ 0.05021
# vol=========   331.31
# sell-buy: 0.05021 331.31
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 3 5040.0 4955.0
# res_before 5027 2 3
# res_after 5027
# ============price================ 0.05027
# vol=========   463.34
# buy-sell: 0.05027 463.34
# sleep: 45s
# ask1 0.0504 bid1 0.04955
# pr before 5027 st 0 5040.0 4955.0
# res_before 5027 1 0
# res_after 5027
# ============price================ 0.05027
# vol=========   385.8
# buy-sell: 0.05027 385.8
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5027 st 1 5040.0 4955.0
# res_before 5026 -1 1
# res_after 5026
# ============price================ 0.05026
# vol=========   430
# buy-sell: 0.05026 430
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 2 5040.0 4955.0
# res_before 5026 0 2
# res_after 5026
# ============price================ 0.05026
# vol=========   229
# buy-sell: 0.05026 229
# sleep: 18s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 3 5040.0 4955.0
# res_before 5023 -1 3
# res_after 5023
# ============price================ 0.05023
# vol=========   319
# sell-buy: 0.05023 319
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 3 5040.0 4955.0
# res_before 5026 1 3
# res_after 5026
# ============price================ 0.05026
# vol=========   234.1
# sell-buy: 0.05026 234.1
# sleep: 47s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 1 5040.0 4955.0
# res_before 5028 2 1
# res_after 5028
# ============price================ 0.05028
# vol=========   226.81
# sell-buy: 0.05028 226.81
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 1 5040.0 4955.0
# res_before 5026 -2 1
# res_after 5026
# ============price================ 0.05026
# vol=========   324.62
# sell-buy: 0.05026 324.62
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 2 5040.0 4955.0
# res_before 5028 1 2
# res_after 5028
# ============price================ 0.05028
# vol=========   431.8
# sell-buy: 0.05028 431.8
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 2 5040.0 4955.0
# res_before 5028 0 2
# res_after 5028
# ============price================ 0.05028
# vol=========   445
# sell-buy: 0.05028 445
# sleep: 13s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 3 5040.0 4955.0
# res_before 5028 0 3
# res_after 5028
# ============price================ 0.05028
# vol=========   451
# sell-buy: 0.05028 451
# sleep: 46s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 3 5040.0 4955.0
# res_before 5031 1 3
# res_after 5031
# ============price================ 0.05031
# vol=========   224.2
# buy-sell: 0.05031 224.2
# sleep: 37s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 3 5040.0 4955.0
# res_before 5031 0 3
# res_after 5031
# ============price================ 0.05031
# vol=========   180.68
# buy-sell: 0.05031 180.68
# sleep: 15s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 2 5040.0 4955.0
# res_before 5027 -2 2
# res_after 5027
# ============price================ 0.05027
# vol=========   483.81
# sell-buy: 0.05027 483.81
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5027 st 1 5040.0 4955.0
# res_before 5026 -1 1
# res_after 5026
# ============price================ 0.05026
# vol=========   361.7
# sell-buy: 0.05026 361.7
# sleep: 48s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 3 5040.0 4955.0
# res_before 5032 2 3
# res_after 5032
# ============price================ 0.05032
# vol=========   272.4
# buy-sell: 0.05032 272.4
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5032 st 3 5040.0 4955.0
# res_before 5029 -1 3
# res_after 5029
# ============price================ 0.05029
# vol=========   195.0
# buy-sell: 0.05029 195.0
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5029 st 1 5040.0 4955.0
# res_before 5031 2 1
# res_after 5031
# ============price================ 0.05031
# vol=========   381.8
# buy-sell: 0.05031 381.8
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 2 5040.0 4955.0
# res_before 5033 1 2
# res_after 5033
# ============price================ 0.05033
# vol=========   392
# sell-buy: 0.05033 392
# sleep: 39s
# ask1 0.0504 bid1 0.04955
# pr before 5033 st 1 5040.0 4955.0
# res_before 5034 1 1
# res_after 5034
# ============price================ 0.05034
# vol=========   382.1
# buy-sell: 0.05034 382.1
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5034 st 0 5040.0 4955.0
# res_before 5034 -1 0
# res_after 5034
# ============price================ 0.05034
# vol=========   252
# buy-sell: 0.05034 252
# sleep: 43s
# ask1 0.0504 bid1 0.04955
# pr before 5034 st 0 5040.0 4955.0
# res_before 5034 -2 0
# res_after 5034
# ============price================ 0.05034
# vol=========   351
# sell-buy: 0.05034 351
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5034 st 3 5040.0 4955.0
# res_before 5028 -2 3
# res_after 5028
# ============price================ 0.05028
# vol=========   365.8
# sell-buy: 0.05028 365.8
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 0 5040.0 4955.0
# res_before 5028 -2 0
# res_after 5028
# ============price================ 0.05028
# vol=========   328.3
# buy-sell: 0.05028 328.3
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 1 5040.0 4955.0
# res_before 5029 1 1
# res_after 5029
# ============price================ 0.05029
# vol=========   485
# sell-buy: 0.05029 485
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5029 st 1 5040.0 4955.0
# res_before 5027 -2 1
# res_after 5027
# ============price================ 0.05027
# vol=========   383
# sell-buy: 0.05027 383
# sleep: 14s
# ask1 0.0504 bid1 0.04955
# pr before 5027 st 1 5040.0 4955.0
# res_before 5025 -2 1
# res_after 5025
# ============price================ 0.05025
# vol=========   462.8
# buy-sell: 0.05025 462.8
# sleep: 12s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 0 5040.0 4955.0
# res_before 5025 -1 0
# res_after 5025
# ============price================ 0.05025
# vol=========   320.0
# sell-buy: 0.05025 320.0
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 3 5040.0 4955.0
# res_before 5022 -1 3
# res_after 5022
# ============price================ 0.05022
# vol=========   198.6
# buy-sell: 0.05022 198.6
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5022 st 3 5040.0 4955.0
# res_before 5019 -1 3
# res_after 5019
# ============price================ 0.05019
# vol=========   259
# buy-sell: 0.05019 259
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 3 5040.0 4955.0
# res_before 5019 0 3
# res_after 5019
# ============price================ 0.05019
# vol=========   433.3
# sell-buy: 0.05019 433.3
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 1 5040.0 4955.0
# res_before 5020 1 1
# res_after 5020
# ============price================ 0.0502
# vol=========   221
# buy-sell: 0.0502 221
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5020 st 2 5040.0 4955.0
# res_before 5024 2 2
# res_after 5024
# ============price================ 0.05024
# vol=========   356.22
# buy-sell: 0.05024 356.22
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5024 st 0 5040.0 4955.0
# res_before 5024 0 0
# res_after 5024
# ============price================ 0.05024
# vol=========   394.43
# buy-sell: 0.05024 394.43
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5024 st 2 5040.0 4955.0
# res_before 5022 -1 2
# res_after 5022
# ============price================ 0.05022
# vol=========   494.97
# buy-sell: 0.05022 494.97
# sleep: 40s
# ask1 0.0504 bid1 0.04955
# pr before 5022 st 1 5040.0 4955.0
# res_before 5020 -2 1
# res_after 5020
# ============price================ 0.0502
# vol=========   158
# sell-buy: 0.0502 158
# sleep: 35s
# ask1 0.0504 bid1 0.04955
# pr before 5020 st 1 5040.0 4955.0
# res_before 5021 1 1
# res_after 5021
# ============price================ 0.05021
# vol=========   490.1
# buy-sell: 0.05021 490.1
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5021 st 3 5040.0 4955.0
# res_before 5015 -2 3
# res_after 5015
# ============price================ 0.05015
# vol=========   499.2
# buy-sell: 0.05015 499.2
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5015 st 1 5040.0 4955.0
# res_before 5015 0 1
# res_after 5015
# ============price================ 0.05015
# vol=========   424.84
# buy-sell: 0.05015 424.84
# sleep: 36s
# ask1 0.0504 bid1 0.04955
# pr before 5015 st 2 5040.0 4955.0
# res_before 5019 2 2
# res_after 5019
# ============price================ 0.05019
# vol=========   444
# sell-buy: 0.05019 444
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5019 st 3 5040.0 4955.0
# res_before 5022 1 3
# res_after 5022
# ============price================ 0.05022
# vol=========   165
# sell-buy: 0.05022 165
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5022 st 3 5040.0 4955.0
# res_before 5028 2 3
# res_after 5028
# ============price================ 0.05028
# vol=========   168
# sell-buy: 0.05028 168
# sleep: 45s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 0 5040.0 4955.0
# res_before 5028 2 0
# res_after 5028
# ============price================ 0.05028
# vol=========   209.3
# buy-sell: 0.05028 209.3
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 1 5040.0 4955.0
# res_before 5026 -2 1
# res_after 5026
# ============price================ 0.05026
# vol=========   480
# buy-sell: 0.05026 480
# sleep: 30s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 2 5040.0 4955.0
# res_before 5026 0 2
# res_after 5026
# ============price================ 0.05026
# vol=========   334.9
# sell-buy: 0.05026 334.9
# sleep: 34s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 3 5040.0 4955.0
# res_before 5029 1 3
# res_after 5029
# ============price================ 0.05029
# vol=========   518.3
# sell-buy: 0.05029 518.3
# sleep: 27s
# ask1 0.0504 bid1 0.04955
# pr before 5029 st 1 5040.0 4955.0
# res_before 5028 -1 1
# res_after 5028
# ============price================ 0.05028
# vol=========   341.11
# sell-buy: 0.05028 341.11
# sleep: 25s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 1 5040.0 4955.0
# res_before 5028 0 1
# res_after 5028
# ============price================ 0.05028
# vol=========   538.3
# sell-buy: 0.05028 538.3
# sleep: 14s
# ask1 0.0504 bid1 0.04955
# pr before 5028 st 3 5040.0 4955.0
# res_before 5031 1 3
# res_after 5031
# ============price================ 0.05031
# vol=========   363
# buy-sell: 0.05031 363
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 2 5040.0 4955.0
# res_before 5033 1 2
# res_after 5033
# ============price================ 0.05033
# vol=========   231
# buy-sell: 0.05033 231
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5033 st 0 5040.0 4955.0
# res_before 5033 1 0
# res_after 5033
# ============price================ 0.05033
# vol=========   467.0
# buy-sell: 0.05033 467.0
# sleep: 9s
# ask1 0.0504 bid1 0.04955
# pr before 5033 st 1 5040.0 4955.0
# res_before 5033 0 1
# res_after 5033
# ============price================ 0.05033
# vol=========   500.4
# buy-sell: 0.05033 500.4
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5033 st 1 5040.0 4955.0
# res_before 5031 -2 1
# res_after 5031
# ============price================ 0.05031
# vol=========   267.2
# sell-buy: 0.05031 267.2
# sleep: 28s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 2 5040.0 4955.0
# res_before 5029 -1 2
# res_after 5029
# ============price================ 0.05029
# vol=========   489.47
# buy-sell: 0.05029 489.47
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5029 st 1 5040.0 4955.0
# res_before 5031 2 1
# res_after 5031
# ============price================ 0.05031
# vol=========   283.22
# sell-buy: 0.05031 283.22
# sleep: 33s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 3 5040.0 4955.0
# res_before 5034 1 3
# res_after 5034
# ============price================ 0.05034
# vol=========   386.9
# sell-buy: 0.05034 386.9
# sleep: 19s
# ask1 0.0504 bid1 0.04955
# pr before 5034 st 3 5040.0 4955.0
# res_before 5031 -1 3
# res_after 5031
# ============price================ 0.05031
# vol=========   459.5
# buy-sell: 0.05031 459.5
# sleep: 27s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 0 5040.0 4955.0
# res_before 5031 -2 0
# res_after 5031
# ============price================ 0.05031
# vol=========   309
# buy-sell: 0.05031 309
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 1 5040.0 4955.0
# res_before 5031 0 1
# res_after 5031
# ============price================ 0.05031
# vol=========   412.0
# buy-sell: 0.05031 412.0
# sleep: 17s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 1 5040.0 4955.0
# res_before 5031 0 1
# res_after 5031
# ============price================ 0.05031
# vol=========   173.2
# sell-buy: 0.05031 173.2
# sleep: 34s
# ask1 0.0504 bid1 0.04955
# pr before 5031 st 3 5040.0 4955.0
# res_before 5025 -2 3
# res_after 5025
# ============price================ 0.05025
# vol=========   404.26
# sell-buy: 0.05025 404.26
# sleep: 42s
# ask1 0.0504 bid1 0.04955
# pr before 5025 st 2 5040.0 4955.0
# res_before 5023 -1 2
# res_after 5023
# ============price================ 0.05023
# vol=========   184.4
# buy-sell: 0.05023 184.4
# sleep: 14s
# ask1 0.0504 bid1 0.04955
# pr before 5023 st 3 5040.0 4955.0
# res_before 5026 1 3
# res_after 5026
# ============price================ 0.05026
# vol=========   250.1
# buy-sell: 0.05026 250.1
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 0 5040.0 4955.0
# res_before 5026 -2 0
# res_after 5026
# ============price================ 0.05026
# vol=========   217.6
# buy-sell: 0.05026 217.6
# sleep: 10s
# ask1 0.0504 bid1 0.04955
# pr before 5026 st 1 5040.0 4955.0
# res_before 5024 -2 1
# res_after 5024
# ============price================ 0.05024
# vol=========   290.9
# sell-buy: 0.05024 290.9
# sleep: 35s
# ask1 0.0504 bid1 0.04955
# pr before 5024 st 3 5040.0 4955.0
# res_before 5024 0 3
# res_after 5024
# ============price================ 0.05024
# vol=========   257
# buy-sell: 0.05024 257
# sleep: 9s
# ...
# ============price================ 0.05014
# vol=========   479.3
# sell-buy: 0.05014 479.3
# sleep: 34s
# ask1 0.05055 bid1 0.04972
# pr before 5014 st 3 5055.0 4972.0
# res_before 5017 1 3
# res_after 5017
# ============price================ 0.05017
# vol=========   291.6
# buy-sell: 0.05017 291.6
# sleep: 45s
# ask1 0.05055 bid1 0.04972
# pr before 5017 st 3 5055.0 4972.0
# res_before 5017 0 3
# res_after 5017
# ============price================ 0.05017
# vol=========   333.6
# sell-buy: 0.05017 333.6
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5017 st 1 5055.0 4972.0
# res_before 5017 0 1
# res_after 5017
# ============price================ 0.05017
# vol=========   488.4
# sell-buy: 0.05017 488.4
# sleep: 43s
# ask1 0.05055 bid1 0.04972
# pr before 5017 st 0 5055.0 4972.0
# res_before 5017 -2 0
# res_after 5017
# ============price================ 0.05017
# vol=========   329
# buy-sell: 0.05017 329
# sleep: 49s
# ask1 0.05055 bid1 0.04972
# pr before 5017 st 2 5055.0 4972.0
# res_before 5019 1 2
# res_after 5019
# ============price================ 0.05019
# vol=========   268.47
# buy-sell: 0.05019 268.47
# sleep: 11s
# ask1 0.05055 bid1 0.04972
# pr before 5019 st 3 5055.0 4972.0
# res_before 5013 -2 3
# res_after 5013
# ============price================ 0.05013
# vol=========   209.8
# buy-sell: 0.05013 209.8
# sleep: 12s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 1 5055.0 4972.0
# res_before 5011 -2 1
# res_after 5011
# ============price================ 0.05011
# vol=========   361.3
# sell-buy: 0.05011 361.3
# sleep: 31s
# ask1 0.05055 bid1 0.04972
# pr before 5011 st 3 5055.0 4972.0
# res_before 5017 2 3
# res_after 5017
# ============price================ 0.05017
# vol=========   242.76
# sell-buy: 0.05017 242.76
# sleep: 28s
# ask1 0.05055 bid1 0.04972
# pr before 5017 st 0 5055.0 4972.0
# res_before 5017 -1 0
# res_after 5017
# ============price================ 0.05017
# vol=========   354.7
# sell-buy: 0.05017 354.7
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5017 st 1 5055.0 4972.0
# res_before 5019 2 1
# res_after 5019
# ============price================ 0.05019
# vol=========   422.39
# sell-buy: 0.05019 422.39
# sleep: 15s
# ask1 0.05055 bid1 0.04972
# pr before 5019 st 0 5055.0 4972.0
# res_before 5019 -1 0
# res_after 5019
# ============price================ 0.05019
# vol=========   400.68
# buy-sell: 0.05019 400.68
# sleep: 21s
# ask1 0.05055 bid1 0.04972
# pr before 5019 st 3 5055.0 4972.0
# res_before 5013 -2 3
# res_after 5013
# ============price================ 0.05013
# vol=========   398.7
# sell-buy: 0.05013 398.7
# sleep: 49s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 0 5055.0 4972.0
# res_before 5013 -2 0
# res_after 5013
# ============price================ 0.05013
# vol=========   438.14
# sell-buy: 0.05013 438.14
# sleep: 25s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 0 5055.0 4972.0
# res_before 5013 1 0
# res_after 5013
# ============price================ 0.05013
# vol=========   438
# sell-buy: 0.05013 438
# sleep: 41s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 3 5055.0 4972.0
# res_before 5010 -1 3
# res_after 5010
# ============price================ 0.0501
# vol=========   461.97
# buy-sell: 0.0501 461.97
# sleep: 37s
# ask1 0.05055 bid1 0.04972
# pr before 5010 st 0 5055.0 4972.0
# res_before 5010 2 0
# res_after 5010
# ============price================ 0.0501
# vol=========   292
# buy-sell: 0.0501 292
# sleep: 49s
# ask1 0.05055 bid1 0.04972
# pr before 5010 st 0 5055.0 4972.0
# res_before 5010 -2 0
# res_after 5010
# ============price================ 0.0501
# vol=========   220
# buy-sell: 0.0501 220
# sleep: 16s
# ask1 0.05055 bid1 0.04972
# pr before 5010 st 2 5055.0 4972.0
# res_before 5012 1 2
# res_after 5012
# ============price================ 0.05012
# vol=========   151
# buy-sell: 0.05012 151
# sleep: 30s
# ask1 0.05055 bid1 0.04972
# pr before 5012 st 0 5055.0 4972.0
# res_before 5012 -1 0
# res_after 5012
# ============price================ 0.05012
# vol=========   321
# sell-buy: 0.05012 321
# sleep: 11s
# ask1 0.05055 bid1 0.04972
# pr before 5012 st 3 5055.0 4972.0
# res_before 5006 -2 3
# res_after 5006
# ============price================ 0.05006
# vol=========   458
# sell-buy: 0.05006 458
# sleep: 37s
# ask1 0.05055 bid1 0.04972
# pr before 5006 st 3 5055.0 4972.0
# res_before 5003 -1 3
# res_after 5003
# ============price================ 0.05003
# vol=========   444
# buy-sell: 0.05003 444
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5003 st 3 5055.0 4972.0
# res_before 4997 -2 3
# res_after 4997
# ============price================ 0.04997
# vol=========   221.3
# sell-buy: 0.04997 221.3
# sleep: 40s
# ask1 0.05055 bid1 0.04972
# pr before 4997 st 1 5055.0 4972.0
# res_before 4998 1 1
# res_after 4998
# ============price================ 0.04998
# vol=========   482.0
# buy-sell: 0.04998 482.0
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 4998 st 3 5055.0 4972.0
# res_before 4992 -2 3
# res_after 4992
# ============price================ 0.04992
# vol=========   304.89
# sell-buy: 0.04992 304.89
# sleep: 27s
# ask1 0.05055 bid1 0.04972
# pr before 4992 st 0 5055.0 4972.0
# res_before 4992 -1 0
# res_after 4992
# ============price================ 0.04992
# vol=========   155.6
# sell-buy: 0.04992 155.6
# sleep: 44s
# ask1 0.05055 bid1 0.04972
# pr before 4992 st 3 5055.0 4972.0
# res_before 4992 0 3
# res_after 4992
# ============price================ 0.04992
# vol=========   494.98
# buy-sell: 0.04992 494.98
# sleep: 14s
# ask1 0.05055 bid1 0.04972
# pr before 4992 st 2 5055.0 4972.0
# res_before 4994 1 2
# res_after 4994
# ============price================ 0.04994
# vol=========   431
# sell-buy: 0.04994 431
# sleep: 16s
# ask1 0.05055 bid1 0.04972
# pr before 4994 st 0 5055.0 4972.0
# res_before 4994 1 0
# res_after 4994
# ============price================ 0.04994
# vol=========   499.5
# sell-buy: 0.04994 499.5
# sleep: 14s
# ask1 0.05055 bid1 0.04972
# pr before 4994 st 3 5055.0 4972.0
# res_before 4997 1 3
# res_after 4997
# ============price================ 0.04997
# vol=========   309.6
# sell-buy: 0.04997 309.6
# sleep: 15s
# ask1 0.05055 bid1 0.04972
# pr before 4997 st 0 5055.0 4972.0
# res_before 4997 -2 0
# res_after 4997
# ============price================ 0.04997
# vol=========   333
# buy-sell: 0.04997 333
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 4997 st 3 5055.0 4972.0
# res_before 4997 0 3
# res_after 4997
# ============price================ 0.04997
# vol=========   275
# sell-buy: 0.04997 275
# sleep: 42s
# ask1 0.05055 bid1 0.04972
# pr before 4997 st 2 5055.0 4972.0
# res_before 4999 1 2
# res_after 4999
# ============price================ 0.04999
# vol=========   267
# buy-sell: 0.04999 267
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 4999 st 2 5055.0 4972.0
# res_before 5003 2 2
# res_after 5003
# ============price================ 0.05003
# vol=========   438
# buy-sell: 0.05003 438
# sleep: 31s
# ask1 0.05055 bid1 0.04972
# pr before 5003 st 0 5055.0 4972.0
# res_before 5003 0 0
# res_after 5003
# ============price================ 0.05003
# vol=========   384.7
# buy-sell: 0.05003 384.7
# sleep: 48s
# ask1 0.05055 bid1 0.04972
# pr before 5003 st 3 5055.0 4972.0
# res_before 4997 -2 3
# res_after 4997
# ============price================ 0.04997
# vol=========   349
# sell-buy: 0.04997 349
# sleep: 40s
# ask1 0.05055 bid1 0.04972
# pr before 4997 st 2 5055.0 4972.0
# res_before 5001 2 2
# res_after 5001
# ============price================ 0.05001
# vol=========   285
# sell-buy: 0.05001 285
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5001 st 3 5055.0 4972.0
# res_before 5001 0 3
# res_after 5001
# ============price================ 0.05001
# vol=========   426.6
# buy-sell: 0.05001 426.6
# sleep: 18s
# ask1 0.05055 bid1 0.04972
# pr before 5001 st 0 5055.0 4972.0
# res_before 5001 1 0
# res_after 5001
# ============price================ 0.05001
# vol=========   407.7
# buy-sell: 0.05001 407.7
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5001 st 3 5055.0 4972.0
# res_before 4998 -1 3
# res_after 4998
# ============price================ 0.04998
# vol=========   264
# sell-buy: 0.04998 264
# sleep: 23s
# ask1 0.05055 bid1 0.04972
# pr before 4998 st 3 5055.0 4972.0
# res_before 4992 -2 3
# res_after 4992
# ============price================ 0.04992
# vol=========   248
# sell-buy: 0.04992 248
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 4992 st 3 5055.0 4972.0
# res_before 4998 2 3
# res_after 4998
# ============price================ 0.04998
# vol=========   408.5
# sell-buy: 0.04998 408.5
# sleep: 33s
# ask1 0.05055 bid1 0.04972
# pr before 4998 st 0 5055.0 4972.0
# res_before 4998 2 0
# res_after 4998
# ============price================ 0.04998
# vol=========   471
# sell-buy: 0.04998 471
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 4998 st 2 5055.0 4972.0
# res_before 4994 -2 2
# res_after 4994
# ============price================ 0.04994
# vol=========   239
# sell-buy: 0.04994 239
# sleep: 14s
# ask1 0.05055 bid1 0.04972
# pr before 4994 st 0 5055.0 4972.0
# res_before 4994 2 0
# res_after 4994
# ============price================ 0.04994
# vol=========   266
# sell-buy: 0.04994 266
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 4994 st 2 5055.0 4972.0
# res_before 4996 1 2
# res_after 4996
# ============price================ 0.04996
# vol=========   440
# sell-buy: 0.04996 440
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 4996 st 0 5055.0 4972.0
# res_before 4996 2 0
# res_after 4996
# ============price================ 0.04996
# vol=========   474.75
# sell-buy: 0.04996 474.75
# sleep: 17s
# ask1 0.05055 bid1 0.04972
# pr before 4996 st 2 5055.0 4972.0
# res_before 5000 2 2
# res_after 5000
# ============price================ 0.05
# vol=========   444.3
# sell-buy: 0.05 444.3
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5000 st 2 5055.0 4972.0
# res_before 5004 2 2
# res_after 5004
# ============price================ 0.05004
# vol=========   473.0
# buy-sell: 0.05004 473.0
# sleep: 20s
# ask1 0.05055 bid1 0.04972
# pr before 5004 st 1 5055.0 4972.0
# res_before 5003 -1 1
# res_after 5003
# ============price================ 0.05003
# vol=========   314
# buy-sell: 0.05003 314
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5003 st 0 5055.0 4972.0
# res_before 5003 -2 0
# res_after 5003
# ============price================ 0.05003
# vol=========   463
# sell-buy: 0.05003 463
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5003 st 2 5055.0 4972.0
# res_before 5003 0 2
# res_after 5003
# ============price================ 0.05003
# vol=========   350.2
# sell-buy: 0.05003 350.2
# sleep: 29s
# ask1 0.05055 bid1 0.04972
# pr before 5003 st 3 5055.0 4972.0
# res_before 5006 1 3
# res_after 5006
# ============price================ 0.05006
# vol=========   444.47
# sell-buy: 0.05006 444.47
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5006 st 2 5055.0 4972.0
# res_before 5002 -2 2
# res_after 5002
# ============price================ 0.05002
# vol=========   202
# sell-buy: 0.05002 202
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5002 st 3 5055.0 4972.0
# res_before 5005 1 3
# res_after 5005
# ============price================ 0.05005
# vol=========   480
# buy-sell: 0.05005 480
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5005 st 1 5055.0 4972.0
# res_before 5004 -1 1
# res_after 5004
# ============price================ 0.05004
# vol=========   385.6
# sell-buy: 0.05004 385.6
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5004 st 3 5055.0 4972.0
# res_before 5010 2 3
# res_after 5010
# ============price================ 0.0501
# vol=========   233
# buy-sell: 0.0501 233
# sleep: 34s
# ask1 0.05055 bid1 0.04972
# pr before 5010 st 2 5055.0 4972.0
# res_before 5006 -2 2
# res_after 5006
# ============price================ 0.05006
# vol=========   447.9
# buy-sell: 0.05006 447.9
# sleep: 28s
# ask1 0.05055 bid1 0.04972
# pr before 5006 st 1 5055.0 4972.0
# res_before 5008 2 1
# res_after 5008
# ============price================ 0.05008
# vol=========   347.6
# sell-buy: 0.05008 347.6
# sleep: 32s
# ask1 0.05055 bid1 0.04972
# pr before 5008 st 0 5055.0 4972.0
# res_before 5008 0 0
# res_after 5008
# ============price================ 0.05008
# vol=========   267
# buy-sell: 0.05008 267
# sleep: 37s
# ask1 0.05055 bid1 0.04972
# pr before 5008 st 2 5055.0 4972.0
# res_before 5008 0 2
# res_after 5008
# ============price================ 0.05008
# vol=========   253.1
# sell-buy: 0.05008 253.1
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5008 st 1 5055.0 4972.0
# res_before 5009 1 1
# res_after 5009
# ============price================ 0.05009
# vol=========   211.3
# buy-sell: 0.05009 211.3
# sleep: 22s
# ask1 0.05055 bid1 0.04972
# pr before 5009 st 2 5055.0 4972.0
# res_before 5013 2 2
# res_after 5013
# ============price================ 0.05013
# vol=========   310.97
# buy-sell: 0.05013 310.97
# sleep: 14s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 0 5055.0 4972.0
# res_before 5013 1 0
# res_after 5013
# ============price================ 0.05013
# vol=========   246
# sell-buy: 0.05013 246
# sleep: 19s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 0 5055.0 4972.0
# res_before 5013 -1 0
# res_after 5013
# ============price================ 0.05013
# vol=========   424.16
# buy-sell: 0.05013 424.16
# sleep: 48s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 1 5055.0 4972.0
# res_before 5014 1 1
# res_after 5014
# ============price================ 0.05014
# vol=========   336.7
# sell-buy: 0.05014 336.7
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5014 st 0 5055.0 4972.0
# res_before 5014 -2 0
# res_after 5014
# ============price================ 0.05014
# vol=========   398.9
# sell-buy: 0.05014 398.9
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5014 st 2 5055.0 4972.0
# res_before 5010 -2 2
# res_after 5010
# ============price================ 0.0501
# vol=========   302.56
# buy-sell: 0.0501 302.56
# sleep: 48s
# ask1 0.05055 bid1 0.04972
# pr before 5010 st 0 5055.0 4972.0
# res_before 5010 1 0
# res_after 5010
# ============price================ 0.0501
# vol=========   334
# buy-sell: 0.0501 334
# sleep: 46s
# ask1 0.05055 bid1 0.04972
# pr before 5010 st 1 5055.0 4972.0
# res_before 5010 0 1
# res_after 5010
# ============price================ 0.0501
# vol=========   481.3
# sell-buy: 0.0501 481.3
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5010 st 3 5055.0 4972.0
# res_before 5016 2 3
# res_after 5016
# ============price================ 0.05016
# vol=========   215
# sell-buy: 0.05016 215
# sleep: 25s
# ask1 0.05055 bid1 0.04972
# pr before 5016 st 3 5055.0 4972.0
# res_before 5013 -1 3
# res_after 5013
# ============price================ 0.05013
# vol=========   251.86
# buy-sell: 0.05013 251.86
# sleep: 30s
# ask1 0.05055 bid1 0.04972
# pr before 5013 st 2 5055.0 4972.0
# res_before 5009 -2 2
# res_after 5009
# ============price================ 0.05009
# vol=========   313
# sell-buy: 0.05009 313
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5009 st 1 5055.0 4972.0
# res_before 5011 2 1
# res_after 5011
# ============price================ 0.05011
# vol=========   169
# buy-sell: 0.05011 169
# sleep: 21s
# ask1 0.05055 bid1 0.04972
# pr before 5011 st 0 5055.0 4972.0
# res_before 5011 -2 0
# res_after 5011
# ============price================ 0.05011
# vol=========   489
# buy-sell: 0.05011 489
# sleep: 40s
# ask1 0.05055 bid1 0.04972
# pr before 5011 st 2 5055.0 4972.0
# res_before 5007 -2 2
# res_after 5007
# ============price================ 0.05007
# vol=========   181
# sell-buy: 0.05007 181
# sleep: 9s
# ask1 0.05055 bid1 0.04972
# pr before 5007 st 0 5055.0 4972.0
# res_before 5007 2 0
# res_after 5007
# ============price================ 0.05007
# vol=========   500
# sell-buy: 0.05007 500
# sleep: 10s
# ask1 0.05055 bid1 0.04972
# pr before 5007 st 2 5055.0 4972.0
# res_before 5003 -2 2
# res_after 5003
# ============price================ 0.05003
# vol=========   159
# sell-buy: 0.05003 159
# sleep: 40s
# ask1 0.05055 bid1 0.04972
# pr before 5003 st 1 5055.0 4972.0
# res_before 5001 -2 1
# res_after 5001
# ============price================ 0.05001
# vol=========   284
# sell-buy: 0.05001 284
# sleep: 40s
# ask1 0.05055 bid1 0.04972
# pr before 5001 st 0 5055.0 4972.0
# res_before 5001 0 0
# res_after 5001
# ============price================ 0.05001
# vol=========   427.4
# sell-buy: 0.05001 427.4
# sleep: 34s
# ask1 0.05055 bid1 0.04972
# pr before 5001 st 1 5055.0 4972.0
# res_before 4999 -2 1
# res_after 4999
# ============price================ 0.04999
# vol=========   378.93
# sell-buy: 0.04999 378.93
# sleep: 36s
# ask1 0.05055 bid1 0.04972
# pr before 4999 st 2 5055.0 4972.0
# res_before 4995 -2 2
# res_after 4995
# ============price================ 0.04995
# vol=========   273
# sell-buy: 0.04995 273
# sleep: 27s
# ask1 0.05055 bid1 0.04972
# pr before 4995 st 2 5055.0 4972.0
# res_before 4991 -2 2
# res_after 4991
# ============price================ 0.04991
# vol=========   246
# sell-buy: 0.04991 246
# sleep: 30s
# ask1 0.05055 bid1 0.04972
# pr before 4991 st 0 5055.0 4972.0
# res_before 4991 -1 0
# res_after 4991
# ============price================ 0.04991
# vol=========   448.8
# sell-buy: 0.04991 448.8
# sleep: 32s

# %%
# coding: utf-8
import requests
import hashlib
import random
import time

def res2dict(rese, orderid_list, direc):
    if direc=='B':  #小于bid2满足条件
        for order in rese['orders']:
            if float(order['price'])<bid2:
                orderid_list.append(order['orderid'])
    else:           #大于ask2满足条件
        for order in rese['orders']:
            if float(order['price'])>ask2:
                orderid_list.append(order['orderid'])
    return orderid_list
    
def buy(price_buy,vosl_buy):
    sign_str = "B2"+"SWAG_AUC"+"2"+str(vol)+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"SWAGEXCHANG1@wdquan.cn"+str(price_buy)+"322276"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "https://www.bitnoah.com/intf/v2.jsp?"+"cid=2&"+"coin=SWAG_AUC&"+"funcid=2&"+"phone=SWAGEXCHANG1@wdquan.cn&"+\
    "passwd="+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=322276"+"&price="+str(price_buy)+"&num="+str(vol)+"&bs=B"
    r = requests.get(url)
    res = r.text.replace("\n","")
    #print (res)

def sell(price_sell,vol_sell):
    sign_str = "S2"+"SWAG_AUC"+"2"+str(vol)+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"SWAGEXCHANG1@wdquan.cn"+str(price_sell)+"322276"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "https://www.bitnoah.com/intf/v2.jsp?"+"cid=2&"+"coin=SWAG_AUC&"+"funcid=2&"+"phone=SWAGEXCHANG1@wdquan.cn&"+\
    "passwd="+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=322276"+"&price="+str(price_sell)+"&num="+str(vol)+"&bs=S"
    r = requests.get(url)
    res = r.text.replace("\n","")
    #print (res)
    
while True:
    sign_str = "2"+"SWAG_AUC"+"1"+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"SWAGEXCHANG1@wdquan.cn"+"322276"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "https://www.bitnoah.com/intf/v2.jsp?"+"cid=2&"+"coin=SWAG_AUC&"+"funcid=1&"+"phone=SWAGEXCHANG1@wdquan.cn&"+\
    "passwd="+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=322276"
    r = requests.get(url)
    res = r.text
    rese = eval(res)
    #print (rese)
    #print (rese)

    ask2 = float(rese['sales'][2]['price'])
    bid2 = float(rese['buys'][2]['price'])
    ask10 = float(rese['sales'][7]['price'])
    bid10 = float(rese['buys'][7]['price'])
    print ("ask2",ask2,"bid2",bid2,"aks10",ask10,"bid10",bid10)

    #在价格之外下一个单子

    direc = random.randint(0,1)
    vol = random.randint(1000,3000)

    if direc==1:
        #下一个卖单，比ask2大，ask10小的
        priceR = random.randint(int(ask2*1e5), int(ask10*1e5))
        price = '0.0' + str(priceR)
        print ("make orders, sell, price", price)
        sell(price,vol)      
    else:
        priceR = random.randint(max(int(bid10*1e5),1000), int(bid2*1e5))
        price = '0.0' + str(priceR)
        print ("make orders, buy, price", price)
        buy(price,vol) 

    orderid_list = []

    #先撤掉自己的单子，假如不是前两个位置的单子, 撤掉一个符合条件的单子
    sign_str = "B"+"2"+"SWAG_AUC"+"6"+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"SWAGEXCHANG1@wdquan.cn"+"322276"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "https://www.bitnoah.com/intf/v2.jsp?"+"cid=2&"+"coin=SWAG_AUC&"+"funcid=6&"+"phone=SWAGEXCHANG1@wdquan.cn&"+\
    "passwd="+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=322276&"+"bs=B"
    r_order = requests.get(url)
    rese = eval(r_order.text)
    #print ('myorders',rese)
    orderid_list = res2dict(rese,orderid_list,"B")

    sign_str = "S"+"2"+"SWAG_AUC"+"6"+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"SWAGEXCHANG1@wdquan.cn"+"322276"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "https://www.bitnoah.com/intf/v2.jsp?"+"cid=2&"+"coin=SWAG_AUC&"+"funcid=6&"+"phone=SWAGEXCHANG1@wdquan.cn&"+\
    "passwd="+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&"+"userid=322276&"+"bs=S"
    r_order = requests.get(url)
    rese = eval(r_order.text)
    #print ('myorders',rese)
    orderid_list = res2dict(rese,orderid_list,"S")




    cancelId = random.choice(orderid_list)
    #print (orderid_list,cancelId)
    sign_str = "2"+"SWAG_AUC"+"3"+cancelId+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"SWAGEXCHANG1@wdquan.cn"+"322276"+"29e7cd1355568058051e313c5h10d6wd882d2d9487984a2v083958d07fQ1eeM0"
    sign_res = hashlib.md5(sign_str.encode('utf-8')).hexdigest()
    url = "https://www.bitnoah.com/intf/v2.jsp?"+"cid=2&"+"coin=SWAG_AUC&"+"funcid=3&"+"phone=SWAGEXCHANG1@wdquan.cn&"+\
    "passwd="+hashlib.md5("SWAG20180807".encode('utf-8')).hexdigest()+"&"+"sign="+sign_res+"&orderid="+cancelId+"&userid=322276"+""
    r = requests.get(url)
    res = r.text.replace("\n","")
    print  ("res",res)
    print ("orderid_list",len(orderid_list))
    time.sleep(1)
